# %% [markdown]
# # 도로명

# %%
#!/usr/bin/env python3
import pandas as pd
import numpy as np

data_df=pd.read_excel("C:\\Users\\intae\\Desktop\\공모전\\도로명정보조회.xls",sheetname='도로명정보조회' )
data_df.head(5)
# Out:
#   총 1436(도로명수 : 685) Unnamed: 1 Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 0                시군구      도로명번호        도로명            로마자표기    읍면동일련번호
# 1                동작구    2000003      남부순환로  Nambusunhwan-ro         00
# 2                동작구    2000003      남부순환로  Nambusunhwan-ro         01
# 3                동작구    2005009       동작대로    Dongjak-daero         00
# 4                동작구    2005009       동작대로    Dongjak-daero         01
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        시도명       시군구명      읍면동구분      읍면동코드       읍면동명
# 1      서울특별시        동작구          2        NaN        NaN
# 2      서울특별시        동작구          1        107        사당동
# 3      서울특별시        동작구          2        NaN        NaN
# 4      서울특별시        동작구          1        106        동작동

# %%
# 칼럼명 제대로
data_df.columns = [''] * len(data_df.columns)
data_df.columns=['시군구','도로명번호','도로명','로마자표기','읍면동일련번호','시도명','시군구명','읍면동구분','읍면동코드','읍면동명']
data_df=data_df.drop(0, inplace=False)

# 추출
data_df= data_df[data_df['읍면동일련번호']=='00']
data_df=data_df['도로명']
data_df=data_df.reset_index()
data_df=data_df.drop(['index'],axis=1,inplace=False)
data_df.head()
# Out:
#      도로명
# 0  남부순환로
# 1   동작대로
# 2   시흥대로
# 3  올림픽대로
# 4   보라매로

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 685 entries, 0 to 684
# Data columns (total 1 columns):
# 도로명    685 non-null object
# dtypes: object(1)
# memory usage: 5.4+ KB

# %% [markdown]
# # 안전비상벨

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\안전비상벨위치.csv",encoding='euc-kr')
data1_df.head(5)
# Out:
#   안전비상벨관리번호  설치목적  설치장소유형       설치위치           소재지도로명주소  소재지지번주소         위도  \
# 0      방범-1     1      99  도로명 주소 참조        장승배기로23길 10      NaN  37.510141
# 1      방범-2     1      99  도로명 주소 참조  노량진로8길 40 마당쇠숯불갈비      NaN  37.512401
# 2      방범-3     1      99  도로명 주소 참조        장승배기로18길 27      NaN  37.507402
# 3      방범-4     1      99  도로명 주소 참조          만양로14다길 7      NaN  37.511299
# 4      방범-5     1      99  도로명 주소 참조        장승배기로22길 44      NaN  37.508595
#
#            경도  연계방식 경찰연계유무 경비업체연계유무 관리사무소연계유무                 부가기능  안전비상벨설치년도  \
# 0  126.939452     3      N        N         N  CCTV 관제센터와 양방향 통화기능       2015
# 1  126.937588     3      N        N         N  CCTV 관제센터와 양방향 통화기능       2016
# 2  126.941599     3      N        N         N  CCTV 관제센터와 양방향 통화기능       2017
# 3  126.945310     3      N        N         N  CCTV 관제센터와 양방향 통화기능       2012
# 4  126.941561     3      N        N         N  CCTV 관제센터와 양방향 통화기능       2012
#
#        최종점검일자 최종점검결과구분 관리기관명     관리기관전화번호     데이터기준일자
# 0  2019-10-22        Y  동작구청  02-820-2906  2019-11-28
# 1  2019-10-22        Y  동작구청  02-820-2906  2019-11-28
# 2  2019-10-22        Y  동작구청  02-820-2906  2019-11-28
# 3  2019-10-22        Y  동작구청  02-820-2906  2019-11-28
# 4  2019-10-22        Y  동작구청  02-820-2906  2019-11-28

# %%
# 도로명주소 추출 후 칼럼 추출
data1_df = data1_df[['소재지도로명주소']]
data1_df[['소재지도로명주소','dd']]=data1_df['소재지도로명주소'].str.split(' ', n=1, expand=True)
data1_df=data1_df.drop(['dd'],axis=1,inplace=False)

# 지번주소 인덱스 삭제
for name in data1_df['소재지도로명주소']:
    if name=='서울특별시':
        data1_df=data1_df.drop(data1_df[data1_df['소재지도로명주소']==name].index,inplace=False,axis=0)

# 오기된 도로명주소 행 삭제
for address in data1_df['소재지도로명주소']:
    if address not in list(data_df['도로명'].values):
        data1_df = data1_df.drop(data1_df[data1_df['소재지도로명주소']==address].index, inplace=False, axis=0)
        
data1_df
# Out:
#       소재지도로명주소
# 0     장승배기로23길
# 1       노량진로8길
# 2     장승배기로18길
# 3      만양로14다길
# 4     장승배기로22길
# 5    장승배기로19다길
# 6    장승배기로24가길
# 7      노량진로26길
# 8      노량진로18길
# 9       상도로60길
# 10      상도로67길
# 11     상도로41가길
# 12         상도로
# 13     상도로47다길
# 14      상도로56길
# 15     상도로15마길
# 16     상도로15아길
# 17     상도로26가길
# 18       만양로1길
# 19       대방동2길
# 20      국사봉10길
# 21      성대로6가길
# 22       국사봉5길
# 23     성대로21가길
# 24      성대로10길
# 25      성대로31길
# 26      양녕로28길
# 28      서달로10길
# 29       흑석로3길
# 30       서달로6길
# ..         ...
# 489   동작대로35아길
# 490        상도로
# 491      장승배기로
# 492      여의대방로
# 493       알마타길
# 494      장승배기로
# 495        서달로
# 496        사당로
# 497     상도로50길
# 498     성대로12길
# 499      서달로2길
# 500      흑석한강로
# 501    동작대로17길
# 502   여의대방로36길
# 503      강남초등길
# 504     사당로17길
# 505      신대방2길
# 506        성대로
# 507    동작대로41길
# 508      여의대방로
# 509       대방동길
# 510        양녕로
# 511     상도로56길
# 512        양녕로
# 513        만양로
# 514        만양로
# 515        등용로
# 516        매봉로
# 517      장승배기로
# 518    사당로23나길
#
# [495 rows x 1 columns]

# %%
# 개수 세기
addresses_count={}
for address in list(data1_df['소재지도로명주소']):
    try:
        addresses_count[address]+=1
    except:
        addresses_count[address]=1
print(addresses_count)
# Out:
# {'장승배기로23길': 1, '노량진로8길': 1, '장승배기로18길': 1, '만양로14다길': 1, '장승배기로22길': 1, '장승배기로19다길': 1, '장승배기로24가길': 1, '노량진로26길': 5, '노량진로18길': 1, '상도로60길': 1, '상도로67길': 1, '상도로41가길': 2, '상도로': 10, '상도로47다길': 1, '상도로56길': 2, '상도로15마길': 1, '상도로15아길': 1, '상도로26가길': 1, '만양로1길': 1, '대방동2길': 2, '국사봉10길': 3, '성대로6가길': 4, '국사봉5길': 1, '성대로21가길': 1, '성대로10길': 2, '성대로31길': 1, '양녕로28길': 3, '서달로10길': 1, '흑석로3길': 3, '서달로6길': 2, '대방동13길': 1, '등용로4길
, '만양로13길': 1, '장승배기로16길': 3, '노량진로8나길': 2, '노량진로8다길': 1, '장승배기로9길': 1, '상도로34길': 1, '상도로15다길': 1, '성대로2길': 1, '상도로22나길': 1, '성대로25길': 1, '성대로10나길': 1, '여의대방로24사길': 1, '신대방16가길': 2, '신대방18길': 1, '여의대방로22길': 2, '보라매로9라길': 1, '상도로68길': 2, '상도로45길': 1, '상도로61길': 1, '만양로2길': 3, '상도로13가길': 1, '성대로19길': 1, '흑석로6길': 2, '서달로13길': 1, '서달로10라길': 1, '흑석로10길': 1, '남부순환로269길': 3, '남부순환로271가길': 1, '남부순환로267길': 1, '동작대로41길': 2, '동작대로27라길': 1, '사당로9가길': 1, '사당로18길': 1, '남부순환로257길': 1, '사당로16아길': 1, '사당로2길': 1, '사당로10길': 2, '여의대방로22가길': 1, '여의대방로22바길': 2, '만양로14아길': 1, '상도로22길': 1, '성대로11가길': 1, '현충로10길': 1, '동작대로21길': 1, '동작대로9다길': 1, '동작대로29다길': 1, '동작대로33바길': 1, '사당로29가길': 1, '사당로10가길': 1, '보라매로15길': 1, '성대로16길': 1, '상도로47사길': 1, '상도로12길': 1, '서달로14나길': 1, '동작대로27가길': 1, '사당로17나길': 1, '사당로16가길': 1, '성대로5길': 1, '상도로37길': 1, '장승배기로17길': 1, '남부순환로255길': 1, '장승배기로10가길': 1, '흑석로11길': 1, '노량진로10길': 1, '상도로13길': 1, '흑석로7길': 1, '동작대로9나길': 1, '동작대로33라길': 1, '보라매로': 2, '만양로16길': 1, '성대로1길': 1, '사당로25길': 1, '여의대방로36길': 3, '여의대방로2길': 1, '현충로': 3, '대방동6길': 1, '장승배기로4길': 1, '사당로20나길': 1, '장승배기로19라길': 1, '매봉로6길': 1, '국사봉길': 1, '상도로47라길': 1, '동작대로9길': 1, '상도로30길': 1, '사당로9다길': 1, '사당로9나길': 1, '사당로4길': 2, '서달로14마길': 1, '사당로20바길': 1, '동작대로1길': 1, '사당로23나길': 2, '동작대로39가길': 2, '국사봉2라길': 1, '장승배기로13길': 1, '강남초등길': 2, '성대로29길': 1, '대방동1길': 1, '여의대방로16길': 1, '동작대로13길': 1, '흑석로': 4, '성대로21길': 2, '알마타길': 2, '만양로12가길': 1, '서달로': 4, '양녕로36길': 1, '상도로58길': 2, '여의대방로24가길': 1, '사당로16마길': 1, '만양로3길': 1, '양녕로26길': 1, '신대방11길': 1, '여의대방로44길': 1, '장승배기로5길': 1, '양녕로25길': 1, '여의대방로24길': 1, '매봉로2길': 1, '동작대로17길': 3, '상도로50길': 2, '사당로8나길': 2, '동작대로35아길': 1, '성대로12길': 1, '서달로2길': 1, '흑석한강로': 1, '사당로17길' ...

# %%
data2_df=pd.DataFrame.from_records([addresses_count])
data2_df=data2_df.transpose().reset_index()
data2_df.rename(columns={'index': '도로명', 0: '안전비상벨 개수'}, inplace=True)
data2_df
# Out:
#             도로명  안전비상벨 개수
# 0         강남초등길         2
# 1        국사봉10길         3
# 2        국사봉16길         1
# 3         국사봉1길         3
# 4         국사봉2길         1
# 5        국사봉2나길         1
# 6        국사봉2라길         1
# 7         국사봉5길         1
# 8         국사봉6길         1
# 9         국사봉8길         2
# 10         국사봉길         1
# 11    남부순환로255길         1
# 12   남부순환로255나길         1
# 13   남부순환로255라길         1
# 14   남부순환로255바길         1
# 15   남부순환로257가길         3
# 16    남부순환로257길         1
# 17    남부순환로259길         1
# 18    남부순환로263길         1
# 19    남부순환로265길         1
# 20    남부순환로267길         1
# 21   남부순환로267나길         1
# 22    남부순환로269길         3
# 23   남부순환로271가길         1
# 24    남부순환로271길         2
# 25         노량진로         6
# 26      노량진로10길         1
# 27      노량진로14길         2
# 28     노량진로14나길         1
# 29      노량진로16길         1
# ..          ...       ...
# 266    장승배기로17길         1
# 267    장승배기로18길         1
# 268    장승배기로19길         3
# 269   장승배기로19다길         1
# 270   장승배기로19라길         1
# 271    장승배기로20길         2
# 272    장승배기로22길         1
# 273    장승배기로23길         1
# 274   장승배기로24가길         1
# 275    장승배기로26길         2
# 276     장승배기로4길         1
# 277     장승배기로5길         1
# 278     장승배기로9길         1
# 279    장승배기로9나길         1
# 280         현충로         3
# 281      현충로10길         1
# 282      현충로12길         2
# 283      현충로18길         1
# 284      현충로22길         2
# 285         흑석로         4
# 286      흑석로10길         1
# 287      흑석로11길         1
# 288      흑석로13길         1
# 289     흑석로13마길         1
# 290       흑석로3길         3
# 291       흑석로5길         3
# 292       흑석로6길         2
# 293       흑석로7길         1
# 294       흑석로9길         3
# 295       흑석한강로         1
#
# [296 rows x 2 columns]

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')

# %%
data_df['안전비상벨 개수'] = data_df['안전비상벨 개수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수
# 0        남부순환로         0
# 1         동작대로         2
# 2         시흥대로         0
# 3        올림픽대로         0
# 4         보라매로         2
# 5          솔밭로         4
# 6          양녕로         9
# 7          노들로         0
# 8          대림로         1
# 9        여의대방로         6
# 10         등용로         3
# 11         만양로         8
# 12         매봉로         3
# 13         사당로         3
# 14         상도로        10
# 15         서달로         4
# 16         성대로        14
# 17       장승배기로        11
# 18         현충로         3
# 19         흑석로         4
# 20        노량진로         6
# 21       흑석한강로         1
# 22      강남초등2길         0
# 23      강남초등4길         0
# 24      강남초등6길         0
# 25      강남초등8길         0
# 26       강남초등길         2
# 27      관악로30길         0
# 28      국사봉10길         3
# 29      국사봉12길         0
# ..         ...       ...
# 655    흑석로10라길         0
# 656    흑석로10마길         0
# 657     흑석로11길         1
# 658    흑석로13가길         0
# 659     흑석로13길         1
# 660    흑석로13나길         0
# 661    흑석로13다길         0
# 662    흑석로13라길         0
# 663    흑석로13마길         1
# 664    흑석로13바길         0
# 665    흑석로15가길         0
# 666     흑석로15길         0
# 667    흑석로15나길         0
# 668     흑석로17길         0
# 669     흑석로3가길         0
# 670      흑석로3길         3
# 671      흑석로5길         3
# 672     흑석로6가길         0
# 673      흑석로6길         2
# 674     흑석로6나길         0
# 675      흑석로7길         1
# 676      흑석로8길         0
# 677      흑석로9길         3
# 678    노량진로23길         0
# 679   동작대로39가길         2
# 680  여의대방로24아길         0
# 681     보라매로3길         0
# 682     보라매로5길         0
# 683     보라매로7길         0
# 684   여의대방로20길         0
#
# [685 rows x 2 columns]

# %% [markdown]
# # CCTV

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\CCTV.csv",encoding='euc-kr')
data1_df.head(5)
# Out:
#        관리기관명           소재지도로명주소  소재지지번주소 설치목적구분  카메라대수  카메라화소수  촬영방면정보  보관일수  \
# 0  서울특별시동작구청        장승배기로23길 10      NaN   생활방범      2     NaN     NaN   NaN
# 1  서울특별시동작구청  노량진로8길 40 마당쇠숯불갈비      NaN   생활방범      3     NaN     NaN   NaN
# 2  서울특별시동작구청        장승배기로18길 27      NaN   생활방범      3     NaN     NaN   NaN
# 3  서울특별시동작구청          만양로14다길 7      NaN   생활방범      1     NaN     NaN   NaN
# 4  서울특별시동작구청        장승배기로22길 44      NaN   생활방범      1     NaN     NaN   NaN
#
#    설치년월     관리기관전화번호         위도          경도     데이터기준일자
# 0   NaN  02-820-2906  37.510141  126.939452  2019-11-22
# 1   NaN  02-820-2906  37.512401  126.937588  2019-11-22
# 2   NaN  02-820-2906  37.507402  126.941599  2019-11-22
# 3   NaN  02-820-2906  37.511299  126.945310  2019-11-22
# 4   NaN  02-820-2906  37.508595  126.941561  2019-11-22

# %%
# 도로명주소 추출 후 칼럼 추출
data1_df = data1_df[['소재지도로명주소','카메라대수']]
data1_df[['소재지도로명주소','dd']]=data1_df['소재지도로명주소'].str.split(' ', n=1, expand=True)
data1_df=data1_df.drop(['dd'],axis=1,inplace=False)

# 오기된 도로명주소 행 삭제
for address in data1_df['소재지도로명주소']:
    if address not in list(data_df['도로명'].values):
        data1_df = data1_df.drop(data1_df[data1_df['소재지도로명주소']==address].index, inplace=False, axis=0)

data1_df=data1_df.reset_index()
data1_df=data1_df.drop(['index'],axis=1,inplace=False)
data1_df
# Out:
#       소재지도로명주소  카메라대수
# 0     장승배기로23길      2
# 1       노량진로8길      3
# 2     장승배기로18길      3
# 3      만양로14다길      1
# 4     장승배기로22길      1
# 5    장승배기로19다길      1
# 6    장승배기로24가길      1
# 7      노량진로26길      1
# 8      노량진로18길      3
# 9       상도로60길      3
# 10      상도로67길      4
# 11     상도로41가길      4
# 12         상도로      4
# 13     상도로47다길      4
# 14      상도로56길      4
# 15     상도로15마길      4
# 16     상도로15아길      3
# 17     상도로26가길      3
# 18       만양로1길      3
# 19       대방동2길      3
# 20      국사봉10길      3
# 21      성대로6가길      4
# 22       국사봉5길      4
# 23     성대로21가길      3
# 24      성대로10길      4
# 25      성대로31길      4
# 26      양녕로28길      5
# 27      서달로10길      1
# 28       흑석로3길      3
# 29       서달로6길      3
# ..         ...    ...
# 639     성대로6나길      1
# 640     양녕로25길      1
# 641    서달로12나길      1
# 642       동작대로      1
# 643    동작대로35길      1
# 644     사당로23길      1
# 645     사당로16길      1
# 646    사당로16다길      1
# 647      대방동1길      1
# 648      신대방2길      1
# 649       국사봉길      1
# 650     서달로13길      1
# 651       노량진로      1
# 652        현충로      1
# 653        현충로      1
# 654        서달로     10
# 655   노량진로23가길      4
# 656    노량진로17길      9
# 657        노들로      9
# 658      신대방1길      5
# 659      신대방2길      2
# 660       노량진로      6
# 661    노량진로32길      5
# 662     상도로53길      1
# 663       동작대로      3
# 664       동작대로      1
# 665      신대방1길      1
# 666      신대방2길      1
# 667      신대방2길      1
# 668   여의대방로20길      1
#
# [669 rows x 2 columns]

# %%
addresses=[]
add=[]
for index, address in enumerate(list(data1_df['소재지도로명주소'])):
    address=(address+str(' '))* data1_df.ix[index, ['카메라대수']]
    addresses.extend(address)
for element in addresses:
    dd=str(element).split(sep=' ')
    add.extend(dd)
add
# Out:
# C:\Users\intae\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# ['장승배기로23길',
#  '장승배기로23길',
#  '',
#  '노량진로8길',
#  '노량진로8길',
#  '노량진로8길',
#  '',
#  '장승배기로18길',
#  '장승배기로18길',
#  '장승배기로18길',
#  '',
#  '만양로14다길',
#  '',
#  '장승배기로22길',
#  '',
#  '장승배기로19다길',
#  '',
#  '장승배기로24가길',
#  '',
#  '노량진로26길',
#  '',
#  '노량진로18길',
#  '노량진로18길',
#  '노량진로18길',
#  '',
#  '상도로60길',
#  '상도로60길',
#  '상도로60길',
#  '',
#  '상도로67길',
#  '상도로67길',
#  '상도로67길',
#  '상도로67길',
#  '',
#  '상도로41가길',
#  '상도로41가길',
#  '상도로41가길',
#  '상도로41가길',
#  '',
#  '상도로',
#  '상도로',
#  '상도로',
#  '상도로',
#  '',
#  '상도로47다길',
#  '상도로47다길',
#  '상도로47다길',
#  '상도로47다길',
#  '',
#  '상도로56길',
#  '상도로56길',
#  '상도로56길',
#  '상도로56길',
#  '',
#  '상도로15마길',
#  '상도로15마길',
#  '상도로15마길',
#  '상도로15마길',
#  '',
#  '상도로15아길',
#  '상도로15아길',
#  '상도로15아길',
#  '',
#  '상도로26가길',
#  '상도로26가길',
#  '상도로26가길',
#  '',
#  '만양로1길',
#  '만양로1길',
#  '만양로1길',
#  '',
#  '대방동2길',
#  '대방동2길',
#  '대방동2길',
#  '',
#  '국사봉10길',
#  '국사봉10길',
#  '국사봉10길',
#  '',
#  '성대로6가길',
#  '성대로6가길',
#  '성대로6가길',
#  '성대로6가길',
#  '',
#  '국사봉5길',
#  '국사봉5길',
#  '국사봉5길',
#  '국사봉5길',
#  '',
#  '성대로21가길',
#  '성대로21가길',
#  '성대로21가길',
#  '',
#  '성대로10길',
#  '성대로10길',
#  '성대로10길',
#  '성대로10길',
#  '',
#  '성대로31길',
#  '성대로31길',
#  '성대로31길',
#  '성대로31길',
#  '',
#  '양녕로28길',
#  '양녕로28길',
#  '양녕로28길',
#  '양녕로28길',
#  '양녕로28길',
#  '',
#  '서달로10길',
#  '',
#  '흑석로3길',
#  '흑석로3길',
#  '흑석로3길',
#  '',
#  '서달로6길',
#  '서달로6길',
#  '서달로6길',
#  '',
#  '매봉로',
#  '매봉로',
#  '매봉로',
#  '매봉로',
#  '',
#  '상도로',
#  '상도로',
#  '상도로',
#  '상도로',
#  '',
#  '양녕로28길',
#  '양녕로28길',
#  '양녕로28길',
#  '',
#  '성대로17길',
#  '성대로17길',
#  '성대로17길',
#  '성대로17길',
#  '',
#  '현충로22길',
#  '현충로22길',
#  '현충로22길',
#  '현충로22길',
#  '',
#  '서달로14길',
#  '서달로14길',
#  '서달로14길',
#  '',
#  '동작대로35길',
#  '동작대로35길',
#  '동작대로35길',
#  '동작대로35길',
#  '',
#  '사당로27길',
#  '',
#  '사당로13길',
#  '사당로13길',
#  '사당로13길',
#  '사당로13길',
#  '',
#  '사당로20사길',
#  '사당로20사길',
#  '사당로20사길',
#  '',
#  '사당로2아길',
#  '사당로2아길',
#  '사당로2아길',
#  '',
#  '사당로',
#  '',
#  '대방동길',
#  '대방동길',
#  '대방동길',
#  '대방동길',
#  '',
#  '등용로8가길',
#  '등용로8가길',
#  '등용로8가길',
#  '',
#  '신대방1길',
#  '신대방1길',
#  '신대방1길',
#  '',
#  '보라매로7가길',
#  '보라매로7가길',
#  '보라매로7가길',
#  '보라매로7가길',
#  '',
#  '국사봉2나길',
#  '',
#  '여의대방로10길',
#  '',
#  '신대방2길',
#  '신대방2길',
#  '신대방2길',
#  '신대방2길',
#  '',
#  '보라매로11길',
#  '',
#  '상도로',
#  '',
#  '국사봉16길',
#  '',
#  '양녕로22바길',
#  '양녕로22바길',
#  '양녕로22바길',
#  '',
#  '서달로6길',
#  '',
#  '등용로10나길',
#  '등용로10나길',
#  '등용로10나길',
#  '',
#  '사당로2다길',
#  '사당로2다길',
#  '사당로2다길',
#  '',
#  '노량진로26길',
#  '노량진로26길',
#  '노량진로26길',
#  '노량진로26길',
#  '',
#  '흑석로5길',
#  '흑석로5길',
#  '흑석로5길',
#  '흑석로5길',
#  '',
#  '상도로47길',
#  '상도로47길',
#  '상도로47길',
#  '상도로47길',
#  '',
#  '상도로34다길',
#  '상도로34다길',
#  '상도로34다길',
#  '상도로34다길',
#  '',
#  '성대로37길',
#  '성대로37길',
#  '성대로37길',
#  '성대로37길',
#  '',
#  '국사봉8길',
#  '국사봉8길',
#  '국사봉8길',
#  '국사봉8길',
#  '',
#  '국사봉6길',
#  '국사봉6길',
#  '국사봉6길',
#  '국사봉6길',
#  '',
#  '양녕로25가길',
#  '양녕로25가길',
#  '양녕로25가길',
#  '양녕로25가길',
#  '',
#  '사당로23길',
#  '사당로23길',
#  '사당로23길',
#  '사당로23길',
#  '',
#  '동작대로35길',
#  '동작대로35길',
#  '동작대로35길',
#  '동작대로35길',
#  '',
#  '동작대로33길',
#  '동작대로33길',
#  '동작대로33길',
#  '동작대로33길',
#  '',
#  '동작대로7길',
#  '동작대로7길',
#  '동작대로7길',
#  '동작대로7길',
#  '',
#  '사당로16라길',
#  '사당로16라길',
#  '사당로16라길',
#  '사당로16라길',
#  '사당로16라길',
#  '',
#  '사당로8길',
#  '사당로8길',
#  '사당로8길',
#  '성대로11길',
#  '성대로11길',
#  '성대로11길',
#  '',
#  '서달로12길',
#  '서달로12길',
#  '서달로12길',
#  '',
#  '남부순환로263길',
#  '남부순환로263길',
#  '남부순환로263길',
#  '',
#  '동작대로33가길',
#  '동작대로33가길',
#  '동작대로33가길',
#  '동작대로33가길',
#  '',
#  '사당로23아길',
#  '사당로23아길',
#  '사당로23아길',
#  '',
#  '남부순환로255바길',
#  '남부순환로255바길',
#  '남부순환로255바길',
#  '',
#  '솔밭로',
#  '솔밭로',
#  '솔밭로',
#  '솔밭로',
#  '솔밭로',
#  '',
#  '신대방2나길',
#  '신대방2나길',
#  '신대방2나길',
#  '',
#  '여의대방로22아길',
#  '여의대방로22아길',
#  '여의대방로22아길',
#  '',
#  '현충로14길',
#  '',
#  '만양로10길',
#  '만양로10길',
#  '만양로10길',
#  '',
#  '만양로14길',
#  '만양로14길',
#  '만양로14길',
#  '',
#  '노량진로',
#  '노량진로',
#  '노량진로',
#  '',
#  '만양로',
#  '만양로',
#  '만양로',
#  '',
#  '장승배기로',
#  '장승배기로',
#  '장승배기로',
#  '',
#  '만양로',
#  '만양로',
#  '만양로',
#  '',
#  '만양로',
#  '',
#  '노량진로',
#  '노량진로',
#  '노량진로',
#  '',
#  '노량진로',
#  '노량진로',
#  '노량진로',
#  '',
#  '장승배기로',
#  '장승배기로',
#  '장승배기로',
#  '',
#  '노량진로',
#  '',
#  '노량진로',
#  '노량진로',
#  '노량진로',
#  '',
#  '장승배기로',
#  '장승배기로',
#  '장승배기로',
#  '',
#  '노량진로',
#  '노량진로',
#  '노량진로',
#  '',
#  '상도로15길',
#  '상도로15길',
#  '상도로15길',
#  '',
#  '상도로31길',
#  '상도로31길',
#  '상도로31길',
#  '',
#  '상도로',
#  '',
#  '장승배기로',
#  '장승배기로',
#  '장승배기로',
#  '',
#  '상도로',
#  '상도로',
#  '상도로',
#  '',
#  '장승배기로10길',
#  '장승배기로10길',
#  '장승배기로10길',
#  '',
#  '만양로',
#  '만양로',
#  '만양로',
#  '',
#  '성대로',
#  '성대로',
#  '성대로',
#  '',
#  '상도로',
#  '',
#  '상도로13나길',
#  '상도로13나길',
#  '상도로13나길',
#  '',
#  '상도로',
#  '상도로',
#  '상도로',
#  '',
#  '상도로15사길',
#  '상도로15사길',
#  '상도로15사길',
#  '',
#  '국사봉1길',
#  '국사봉1길',
#  '국사봉1길',
#  '',
#  '성대로',
#  '성대로',
#  '성대로',
#  '',
#  '성대로',
#  '성대로',
#  '성대로',
#  '',
#  '양녕로',
#  '양녕로',
#  '양녕로',
#  '',
#  '성대로',
#  '성대로',
#  '성대로',
#  '',
#  '성대로',
#  '성대로',
#  '성대로',
#  '',
#  '성대로1가길',
#  '성대로1가길',
#  '성대로1가길',
#  '',
#  '성대로',
#  '성대로',
#  '성대로',
#  '',
#  '성대로',
#  '성대로',
#  '성대로',
#  '',
#  '양녕로',
#  '양녕로',
#  '양녕로',
#  '',
#  '등용로',
#  '',
#  '등용로',
#  '등용로',
#  '등용로',
#  '',
#  '여의대방로',
#  '여의대방로',
#  '여의대방로',
#  '',
#  '상도로',
#  '상도로',
#  '상도로',
#  '',
#  '여의대방로24나길',
#  '여의대방로24나길',
#  '여의대방로24나길',
#  '',
#  '여의대방로10가길',
#  '',
#  '신대방14가길',
#  '',
#  '신대방1길',
#  '신대방1길',
#  '신대방1길',
#  '',
#  '여의대방로',
#  '여의대방로',
#  '여의대방로',
#  '',
#  '대림로',
#  '대림로',
#  '대림로',
#  '',
#  '신대방3길',
#  '신대방3길',
#  '신대방3길',
#  '',
#  '신대방6길',
#  '신대방6길',
#  '신대방6길',
#  '',
#  '여의대방로16길',
#  '',
#  '여의대방로',
#  '여의대방로',
#  '여의대방로',
#  '',
#  '보라매로9길',
#  '',
#  '보라매로7가길',
#  '',
#  '국사봉2가길',
#  '',
#  '보라매로17길',
#  '보라매로17길',
#  '보라매로17길',
#  '',
#  '사당로2가길',
#  '사당로2가길',
#  '사당로2가길',
#  '',
#  '상도로55길',
#  '상도로55길',
#  '상도로55길',
#  '',
#  '상도로52길',
#  '상도로52길',
#  '상도로52길',
#  '',
#  '현충로12길',
#  '현충로12길',
#  '현충로12길',
#  '',
#  '양녕로23길',
#  '양녕로23길',
#  '양녕로23길',
#  '',
#  '흑석로6길',
#  '',
#  '서달로10나길',
#  '',
#  '동작대로3길',
#  '동작대로3길',
#  '동작대로3길',
#  '',
#  '동작대로15길',
#  '동작대로15길',
#  '동작대로15길',
#  '',
#  '남부순환로255나길',
#  '남부순환로255나길',
#  '남부순환로255나길',
#  '',
#  '남부순환로271길',
#  '',
#  '동작대로25길',
#  '동작대로25길',
#  '동작대로25길',
#  '',
#  '동작대로31길',
#  '동작대로31길',
#  '동작대로31길',
#  '동작대로31길',
#  '동작대로31길',
#  '',
#  '동작대로',
#  '',
#  '사당로29다길',
#  '사당로29다길',
#  '',
#  '사당로23길',
#  '사당로23길',
#  '사당로23길',
#  '',
#  '사당로27길',
#  '사당로27길',
#  '사당로27길',
#  '',
#  '사당로13길',
#  '사당로13길',
#  '사당로13길',
#  '',
#  '사당로20나길',
#  '',
#  '사당로16가길',
#  '사당로16가길',
#  '사당로16가길',
#  '',
#  '사당로16바길',
#  '',
#  '사당로14가길',
#  '',
#  '사당로8가길',
#  '사당로8가길',
#  '사당로8가길',
#  '',
#  '상도로49길',
#  '상도로49길',
#  '상도로49길',
#  '',
#  '사당로8길',
#  '사당로8길',
#  '사당로8길',
#  '',
#  '노량진로14나길',
#  '노량진로14나길',
#  '노량진로14나길',
#  '',
#  '노량진로32길',
#  '노량진로32길',
#  '노량진로32길',
#  '',
#  '상도로34나길',
#  '상도로34나길',
#  '상도로34나길',
#  '',
#  '현충로18길',
#  '현충로18길',
#  '현충로18길',
#  '',
#  '남부순환로257가길',
#  '남부순환로257가길',
#  '남부순환로257가길',
#  '',
#  '동작대로31길',
#  '동작대로31길',
#  '동작대로31길',
#  '동작대로31길',
#  '',
#  '사당로16나길',
#  '사당로16나길',
#  '사당로16나길',
#  '',
#  '여의대방로62길',
#  '여의대방로62길',
#  '여의대방로62길',
#  '',
#  '여의대방로22나길',
#  '여의대방로22나길',
#  '여의대방로22나길',
#  '',
#  '흑석로3길',
#  '흑석로3길',
#  '흑석로3길',
#  '',
#  '흑석로3길',
#  '흑석로3길',
#  '흑석로3길',
#  '',
#  '흑석로13길',
#  '흑석로13길',
#  '',
#  '흑석로5길',
#  '흑석로5길',
#  '',
#  '흑석로5길',
#  '흑석로5길',
#  '',
#  '흑석로9길',
#  '흑석로9길',
#  '흑석로9길',
#  '흑석로9길',
#  '',
#  '흑석로13마길',
#  '흑석로13마길',
#  '',
#  '보라매로13길',
#  '보라매로13길',
#  '보라매로13길',
#  '',
#  '장승배기로',
#  '장승배기로',
#  '장승배기로',
#  '',
#  '장승배기로26길',
#  '장승배기로26길',
#  '장승배기로26길',
#  '',
#  '사당로16다길',
#  '사당로16다길',
#  ...]

# %%
# 고유값 추출
addresses_count={}
for address in add:
    try:
        addresses_count[address]+=1
    except:
        addresses_count[address]=1
print(addresses_count)
# Out:
# {'장승배기로23길': 2, '': 669, '노량진로8길': 3, '장승배기로18길': 3, '만양로14다길': 1, '장승배기로22길': 1, '장승배기로19다길': 1, '장승배기로24가길': 1, '노량진로26길': 13, '노량진로18길': 3, '상도로60길': 3, '상도로67길': 4, '상도로41가길': 9, '상도로': 43, '상도로47다길': 4, '상도로56길': 7, '상도로15마길': 4, '상도로15아길': 3, '상도로26가길': 3, '만양로1길': 3, '대방동2길': 5, '국사봉10길': 11, '성대로6가길': 11, '국사봉5길': 4, '성대로21가길': 3, '성대로10길': 7, '성대로31길': 4, '양녕로28길': 9, '서달로10길': 1, '흑석로3길': 9, '서달로6길': 4, '대방동13길': 4, '등용로4길': 4, '여의대방로62길': 8, '여의대방로24라길': 3, '신대방2나길': 6, '신대방1길': 15, '신대방2길': 22, '신대방14길': 4, '신대방14가길': 9, '여의대방로22카길': 3, '국사봉2길': 3, '보라매로9길': 5, '여의대방로22라길': 5, '동작대로29가길': 3, '동작대로': 11, '동작대로35가길': 6, '동작대로27길': 5, '동작대로29길': 4, '남부순환로257가길': 7, '남부순환로259길': 3, '사당로20길': 4, '남부순환로265길': 4, '사당로29길': 3, '동작대로35길': 10, '사당로27길': 12, '솔밭로': 12, '사당로2자길': 4, '사당로2차길': 15, '사당로14길': 3, '사당로16길': 21, '남부순환로255라길': 4, '사당로20다길': 5, '노량진로14길': 9, '노량진로30길': 4, '상도로47길': 9, '매봉로': 11, '성대로17길': 8, '현충로22길': 7, '서달로14길': 3, '사당로13길': 7, '사당로20사길': 3, '사당로2아길': 3, '사당로': 17, '대방동길': 14, '등용로8가길': 6, '보라매로7가길': 5, '국사봉2나길': 1, '여의대방로10길': 9, '보라매로11길': 1, '국사봉16길': 1, '양녕로22바길': 3, '등용로10나길': 3, '사당로2다길': 3, '흑석로5길': 8, '상도로34다길': 4, '성대로37길': 4, '국사봉8길': 10, '국사봉6길': 4, '양녕로25가길': 4, '사당로23길': 33, '동작대로33길
 3, '보라매로15길': 3, '성대로16길': 5, '상도로47사길': 4, '상도로12길': 4, '서달로14나길': 4, '동작대로27가길': 4, '사당로17나길': 4, '성대로5길': 4, '상도로37길': 4, '장승배기로17길': 4, '남부순환로255길': 4, '장승배기로10가길': 4, '흑석로11길': 4, '노량진로10길': 4, '상도로13길': 4, '흑석로7길': 4, '동작대로9나길': 4, '동작대로33라길': 6, '보라매로': 8, '여의대방로44길': 9, '여의대방로36길': 9, '현충로': 14, '여의대방로24길': 6, '대방동6길': 1, '동작대로39길': 2, '장승배기로4길': 1, '상도로62가길': 1, '장승배기로19라길': 4, '매봉로6길': 1, '국사봉길': 6, '상도로47라길': 1, '동작대로9길': 3, '상도로30길': 1, '사당로9다길': 1, '사당로9나길': 1, '사당로4길': 5, '서달로14마길': 1, '사당로20바길': 1, '동작대로1길': 3, '사당로23나길': 7, '동작대로39가길': 7, '국사봉2라길': 2, '장승배기로13길': 1, '강남초등길': 8, '만양로12가길': 4, '알마타길': 8, '서달로': 28, '등용로8길': 1, '성대로29길': 4, '대방동1길': 5, '동작대로13길': 13, '흑석로': 17, '성대로21길': 6, '양녕로36길': 3, '상도로58길': 8, '여의대방로24가길': 4, '사당로16마길': 3, '만양로3길': 3, '양녕로26길': 4, '신대방11길': 5, '장승배기로5길': 3, '양녕로25길':  ...

# %%
data2_df=pd.DataFrame.from_records([addresses_count])
data2_df=data2_df.transpose().reset_index()
data2_df.rename(columns={'index': '도로명', 0: 'CCTV 카메라 개수'}, inplace=True)
data2_df=data2_df.drop(0, inplace=False)
data2_df
# Out:
#             도로명  CCTV 카메라 개수
# 1         강남초등길            8
# 2        국사봉10길           11
# 3        국사봉12길            1
# 4        국사봉16길            1
# 5        국사봉1가길            1
# 6         국사봉1길            9
# 7        국사봉2가길            1
# 8         국사봉2길            3
# 9        국사봉2나길            1
# 10       국사봉2라길            2
# 11        국사봉5길            4
# 12        국사봉6길            4
# 13        국사봉7길            1
# 14        국사봉8길           10
# 15         국사봉길            6
# 16    남부순환로255길            4
# 17   남부순환로255나길            3
# 18   남부순환로255라길            4
# 19   남부순환로255바길            3
# 20   남부순환로257가길            7
# 21    남부순환로257길            3
# 22    남부순환로259길            3
# 23    남부순환로263길            3
# 24    남부순환로265길            4
# 25    남부순환로267길            4
# 26   남부순환로267나길            1
# 27    남부순환로269길           13
# 28   남부순환로271가길            3
# 29    남부순환로271길           11
# 30          노들로           12
# ..          ...          ...
# 300    장승배기로18길            3
# 301    장승배기로19길           13
# 302   장승배기로19다길            1
# 303   장승배기로19라길            4
# 304    장승배기로20길            8
# 305    장승배기로22길            1
# 306    장승배기로23길            2
# 307   장승배기로24가길            1
# 308    장승배기로26길            7
# 309     장승배기로4길            1
# 310     장승배기로5길            3
# 311     장승배기로9길            3
# 312    장승배기로9나길            3
# 313         현충로           14
# 314      현충로10길            4
# 315      현충로12길            4
# 316      현충로14길            1
# 317      현충로18길            3
# 318      현충로22길            7
# 319         흑석로           17
# 320      흑석로10길            3
# 321      흑석로11길            4
# 322      흑석로13길            3
# 323     흑석로13마길            2
# 324       흑석로3길            9
# 325       흑석로5길            8
# 326       흑석로6길            5
# 327       흑석로7길            4
# 328       흑석로9길           12
# 329       흑석한강로            3
#
# [329 rows x 2 columns]

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수
# 0        남부순환로         0          NaN
# 1         동작대로         2         11.0
# 2         시흥대로         0          NaN
# 3        올림픽대로         0          NaN
# 4         보라매로         2          8.0
# 5          솔밭로         4         12.0
# 6          양녕로         9         36.0
# 7          노들로         0         12.0
# 8          대림로         1          3.0
# 9        여의대방로         6         21.0
# 10         등용로         3         12.0
# 11         만양로         8         31.0
# 12         매봉로         3         11.0
# 13         사당로         3         17.0
# 14         상도로        10         43.0
# 15         서달로         4         28.0
# 16         성대로        14         49.0
# 17       장승배기로        11         39.0
# 18         현충로         3         14.0
# 19         흑석로         4         17.0
# 20        노량진로         6         26.0
# 21       흑석한강로         1          3.0
# 22      강남초등2길         0          NaN
# 23      강남초등4길         0          NaN
# 24      강남초등6길         0          NaN
# 25      강남초등8길         0          NaN
# 26       강남초등길         2          8.0
# 27      관악로30길         0          NaN
# 28      국사봉10길         3         11.0
# 29      국사봉12길         0          1.0
# ..         ...       ...          ...
# 655    흑석로10라길         0          NaN
# 656    흑석로10마길         0          NaN
# 657     흑석로11길         1          4.0
# 658    흑석로13가길         0          NaN
# 659     흑석로13길         1          3.0
# 660    흑석로13나길         0          NaN
# 661    흑석로13다길         0          NaN
# 662    흑석로13라길         0          NaN
# 663    흑석로13마길         1          2.0
# 664    흑석로13바길         0          NaN
# 665    흑석로15가길         0          NaN
# 666     흑석로15길         0          NaN
# 667    흑석로15나길         0          NaN
# 668     흑석로17길         0          NaN
# 669     흑석로3가길         0          NaN
# 670      흑석로3길         3          9.0
# 671      흑석로5길         3          8.0
# 672     흑석로6가길         0          NaN
# 673      흑석로6길         2          5.0
# 674     흑석로6나길         0          NaN
# 675      흑석로7길         1          4.0
# 676      흑석로8길         0          NaN
# 677      흑석로9길         3         12.0
# 678    노량진로23길         0          NaN
# 679   동작대로39가길         2          7.0
# 680  여의대방로24아길         0          NaN
# 681     보라매로3길         0          NaN
# 682     보라매로5길         0          1.0
# 683     보라매로7길         0          NaN
# 684   여의대방로20길         0          1.0
#
# [685 rows x 3 columns]

# %%
data_df['CCTV 카메라 개수'] = data_df['CCTV 카메라 개수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수
# 0        남부순환로         0            0
# 1         동작대로         2           11
# 2         시흥대로         0            0
# 3        올림픽대로         0            0
# 4         보라매로         2            8
# 5          솔밭로         4           12
# 6          양녕로         9           36
# 7          노들로         0           12
# 8          대림로         1            3
# 9        여의대방로         6           21
# 10         등용로         3           12
# 11         만양로         8           31
# 12         매봉로         3           11
# 13         사당로         3           17
# 14         상도로        10           43
# 15         서달로         4           28
# 16         성대로        14           49
# 17       장승배기로        11           39
# 18         현충로         3           14
# 19         흑석로         4           17
# 20        노량진로         6           26
# 21       흑석한강로         1            3
# 22      강남초등2길         0            0
# 23      강남초등4길         0            0
# 24      강남초등6길         0            0
# 25      강남초등8길         0            0
# 26       강남초등길         2            8
# 27      관악로30길         0            0
# 28      국사봉10길         3           11
# 29      국사봉12길         0            1
# ..         ...       ...          ...
# 655    흑석로10라길         0            0
# 656    흑석로10마길         0            0
# 657     흑석로11길         1            4
# 658    흑석로13가길         0            0
# 659     흑석로13길         1            3
# 660    흑석로13나길         0            0
# 661    흑석로13다길         0            0
# 662    흑석로13라길         0            0
# 663    흑석로13마길         1            2
# 664    흑석로13바길         0            0
# 665    흑석로15가길         0            0
# 666     흑석로15길         0            0
# 667    흑석로15나길         0            0
# 668     흑석로17길         0            0
# 669     흑석로3가길         0            0
# 670      흑석로3길         3            9
# 671      흑석로5길         3            8
# 672     흑석로6가길         0            0
# 673      흑석로6길         2            5
# 674     흑석로6나길         0            0
# 675      흑석로7길         1            4
# 676      흑석로8길         0            0
# 677      흑석로9길         3           12
# 678    노량진로23길         0            0
# 679   동작대로39가길         2            7
# 680  여의대방로24아길         0            0
# 681     보라매로3길         0            0
# 682     보라매로5길         0            1
# 683     보라매로7길         0            0
# 684   여의대방로20길         0            1
#
# [685 rows x 3 columns]

# %% [markdown]
# # 담배소매인 지정 업소

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\담배소매인지정.csv",encoding='euc-kr')
data1_df.head(5)
# Out:
#    일련번호           민원구분              업소명                              업소지번주소  \
# 0     1  제7조의3제2항에따른경우           24서브웨이              서울특별시 동작구 사당동 132번지 6호
# 1     2  제7조의3제2항에따른경우             부산마트            서울특별시 동작구 노량진동 246번지 75호
# 2     3  제7조의3제2항에따른경우  지에스(GS)25 상도건영점           서울특별시 동작구 상도동 414번지 건영아파트
# 3     4  제7조의3제2항에따른경우      지에스25 대방경남점         서울특별시 동작구 대방동 344번지 1호 경준빌딩
# 4     5  제7조의3제2항에따른경우      야호파트너즈 주식회사  서울특별시 동작구 신대방동 395번지 62호 삼성보라매옴니타워
#
#                                              업소도로명주소       업소전화번호        지정일자
# 0                     서울특별시 동작구 동작대로27길 18. 1층 (사당동)          NaN  2019-03-29
# 1                   서울특별시 동작구 장승배기로27길 30. 1층 (노량진동)          NaN  2019-03-29
# 2         서울특별시 동작구 만양로 26. 상가동 2층 211호 (상도동. 건영아파트)          NaN  2019-03-26
# 3               서울특별시 동작구 여의대방로54길 14. 경준빌딩 1층 (대방동)  02-816-0378  2019-03-19
# 4  서울특별시 동작구 보라매로5길 23. 지하1층 b107. b108호 (신대방동. 삼...          NaN  2019-03-19

# %%
# 도로명주소 추출 후 칼럼 추출
data1_df = data1_df[['업소도로명주소']]
data1_df[['a','b','업소도로명','c']]=data1_df['업소도로명주소'].str.split(' ', n=3, expand=True)
data1_df=data1_df.drop(['a','b','c','업소도로명주소'],axis=1,inplace=False)

# 오기된 도로명주소 행 삭제
for address in data1_df['업소도로명']:
    if address not in list(data_df['도로명'].values):
        data1_df = data1_df.drop(data1_df[data1_df['업소도로명']==address].index, inplace=False, axis=0)

# Null 값 제거
data1_df=data1_df.reset_index()
data1_df=data1_df.drop(['index'],axis=1,inplace=False)

data1_df['업소도로명'] = data1_df['업소도로명'].fillna(0)
data1_df=data1_df.drop(data1_df[data1_df['업소도로명']==0].index,axis=0,inplace=False)

data1_df
# Out:
#         업소도로명
# 0     동작대로27길
# 1    장승배기로27길
# 2         만양로
# 3    여의대방로54길
# 4      보라매로5길
# 5      양녕로23길
# 6       성대로1길
# 7      양녕로25길
# 8      상도로41길
# 9         사당로
# 10     상도로22길
# 11   여의대방로16길
# 12    보라매로9가길
# 13        상도로
# 14     서달로10길
# 15     신대방1가길
# 16    사당로23나길
# 17        흑석로
# 18       노량진로
# 19        양녕로
# 20   여의대방로54길
# 21     노량진로6길
# 22     상도로15길
# 23     사당로13길
# 24     신대방1가길
# 25     양녕로23길
# 26        상도로
# 27    사당로14가길
# 28   동작대로35라길
# 29     등용로14길
# ..        ...
# 732      노량진로
# 734    양녕로29길
# 735       상도로
# 737     등용로4길
# 738    사당로2자길
# 739  동작대로27라길
# 740    동작대로7길
# 743  장승배기로19길
# 744    노량진로6길
# 745   동작대로25길
# 747       상도로
# 748   양녕로22나길
# 749    상도로31길
# 750       노들로
# 751   만양로14사길
# 752      노량진로
# 753   사당로16다길
# 755   서달로10라길
# 756     서달로6길
# 757   노량진로18길
# 758      보라매로
# 759   동작대로11길
# 761       만양로
# 762    사당로28길
# 765    상도로60길
# 766   만양로14가길
# 767  동작대로29나길
# 771   사당로16가길
# 773    성대로29길
# 774       상도로
#
# [714 rows x 1 columns]

# %%
# 개수 세기
addresses_count={}
for address in list(data1_df['업소도로명']):
    try:
        addresses_count[address]+=1
    except:
        addresses_count[address]=1
print(addresses_count)
# Out:
# {'동작대로27길': 2, '장승배기로27길': 1, '만양로': 18, '여의대방로54길': 2, '보라매로5길': 5, '양녕로23길': 2, '성대로1길': 2, '양녕로25길': 2, '상도로41길': 2, '사당로': 24, '상도로22길': 4, '여의대방로16길': 3, '보라매로9가길': 1, '상도로': 58, '서달로10길': 5, '신대방1가길': 4, '사당로23나길': 1, '흑석로': 13, '노량진로': 38, '양녕로': 5, '노량진로6길': 5, '상도로15길': 11, '사당로13길': 2, '사당로14가길': 1, '동작대로35라길': 1, '등용로14길': 4, '동작대로31길': 1, '동작대로29길': 15, '사당로27길': 5, '서달로12길': 1, '동작대로27가길': 2, '동작대로': 15, '사당로16바길': 1, '보라매로3길': 1, '상도로50길': 1, '대방동27길': 4, '여의대방로': 11, '보라매로19길': 2, '장승배기로16길': 1, '남부순환로': 6, '남부순환로269길': 3, '장승배기로10길': 3, '여의대방로10길': 2, '상도로41가길': 1, '대방동23길': 2, '만양로14길': 2, '사당로22나길': 1, '상도로53길': 4, '신대방2길': 4, '노량진로8길': 5, '사당로23길': 5, '흑석로6길': 1, '사당로16가길': 3, '서달로14사길': 1, '동작대로13길': 
, '상도로34길': 1, '사당로2차길': 3, '상도로13나길': 1, '양녕로34길': 1, '서달로14길': 1, '동작대로17길': 1, '사당로16아길': 1, '만양로12길': 1, '서달로8가길': 1, '사당로2다길': 1, '노량진로24길': 1, '남부순환로271가길': 1, '사당로2길': 1, '만양로16길': 1, '노량진로10가길': 1, '등용로12길': 2, '동작대로35가길': 2, '서달로2길': 1, '국사봉10길': 1, '노량진로12길': 1, '만양로12가길': 1, '노량진로22길': 1, '성대로2길': 1, '장승배기로10가길': 1, '노량진로16길': 1, '성대로31길': 1, '노량진로10길': 1, '남부순환로255길': 1, '신대방16가길': 1, '동작대로33다길': 1, '양녕로29길': 1, '사당로2자길': 1, '동작대로27라길': 1, '장승배기로19길': 1, '양녕로22나길': 1, '만양로14사길': 1, '사당로16다길': 1, '서달로10라길': 1, '서달로6길': 1, '동작대로11길': 1, '상도로60길': 1}

# %%
data2_df=pd.DataFrame.from_records([addresses_count])
data2_df=data2_df.transpose().reset_index()
data2_df.rename(columns={'index': '도로명', 0: '담배소매인 지정 업소 개수'}, inplace=True)
data2_df
# Out:
#             도로명  담배소매인 지정 업소 개수
# 0        국사봉10길               1
# 1         국사봉1길               8
# 2         국사봉2길               1
# 3         국사봉8길               1
# 4          국사봉길               8
# 5         남부순환로               6
# 6     남부순환로255길               1
# 7    남부순환로255다길               1
# 8     남부순환로259길               1
# 9     남부순환로269길               3
# 10   남부순환로271가길               1
# 11    남부순환로271길               1
# 12          노들로               5
# 13         노량진로              38
# 14     노량진로10가길               1
# 15      노량진로10길               1
# 16      노량진로12길               1
# 17     노량진로14가길               2
# 18      노량진로14길               1
# 19      노량진로16길               1
# 20      노량진로18길               2
# 21      노량진로22길               1
# 22     노량진로23가길               2
# 23      노량진로24길               1
# 24      노량진로26길               2
# 25      노량진로28길               2
# 26       노량진로6길               5
# 27      노량진로6다길               1
# 28       노량진로8길               5
# 29          대림로               5
# ..          ...             ...
# 207   여의대방로24마길               1
# 208   여의대방로24차길               3
# 209    여의대방로36길               3
# 210    여의대방로44길               2
# 211    여의대방로54길               2
# 212    여의대방로62길               1
# 213       장승배기로              22
# 214   장승배기로10가길               1
# 215    장승배기로10길               3
# 216   장승배기로11가길               1
# 217    장승배기로16길               1
# 218   장승배기로19가길               1
# 219    장승배기로19길               1
# 220    장승배기로20길               1
# 221    장승배기로24길               1
# 222    장승배기로27길               1
# 223    장승배기로28길               2
# 224    장승배기로30길               1
# 225         현충로              14
# 226      현충로10길               1
# 227      현충로20길               1
# 228      현충로24길               1
# 229         흑석로              13
# 230       흑석로3길               1
# 231       흑석로5길               1
# 232      흑석로6가길               1
# 233       흑석로6길               1
# 234       흑석로7길               1
# 235       흑석로9길               1
# 236       흑석한강로               2
#
# [237 rows x 2 columns]

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')
data_df['담배소매인 지정 업소 개수'] = data_df['담배소매인 지정 업소 개수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수  담배소매인 지정 업소 개수
# 0        남부순환로         0            0               6
# 1         동작대로         2           11              15
# 2         시흥대로         0            0               6
# 3        올림픽대로         0            0               0
# 4         보라매로         2            8               8
# 5          솔밭로         4           12               2
# 6          양녕로         9           36               5
# 7          노들로         0           12               5
# 8          대림로         1            3               5
# 9        여의대방로         6           21              11
# 10         등용로         3           12              11
# 11         만양로         8           31              18
# 12         매봉로         3           11               7
# 13         사당로         3           17              24
# 14         상도로        10           43              58
# 15         서달로         4           28               7
# 16         성대로        14           49               4
# 17       장승배기로        11           39              22
# 18         현충로         3           14              14
# 19         흑석로         4           17              13
# 20        노량진로         6           26              38
# 21       흑석한강로         1            3               2
# 22      강남초등2길         0            0               0
# 23      강남초등4길         0            0               0
# 24      강남초등6길         0            0               0
# 25      강남초등8길         0            0               0
# 26       강남초등길         2            8               0
# 27      관악로30길         0            0               0
# 28      국사봉10길         3           11               1
# 29      국사봉12길         0            1               0
# ..         ...       ...          ...             ...
# 655    흑석로10라길         0            0               0
# 656    흑석로10마길         0            0               0
# 657     흑석로11길         1            4               0
# 658    흑석로13가길         0            0               0
# 659     흑석로13길         1            3               0
# 660    흑석로13나길         0            0               0
# 661    흑석로13다길         0            0               0
# 662    흑석로13라길         0            0               0
# 663    흑석로13마길         1            2               0
# 664    흑석로13바길         0            0               0
# 665    흑석로15가길         0            0               0
# 666     흑석로15길         0            0               0
# 667    흑석로15나길         0            0               0
# 668     흑석로17길         0            0               0
# 669     흑석로3가길         0            0               0
# 670      흑석로3길         3            9               1
# 671      흑석로5길         3            8               1
# 672     흑석로6가길         0            0               1
# 673      흑석로6길         2            5               1
# 674     흑석로6나길         0            0               0
# 675      흑석로7길         1            4               1
# 676      흑석로8길         0            0               0
# 677      흑석로9길         3           12               1
# 678    노량진로23길         0            0               0
# 679   동작대로39가길         2            7               1
# 680  여의대방로24아길         0            0               0
# 681     보라매로3길         0            0               1
# 682     보라매로5길         0            1               5
# 683     보라매로7길         0            0               0
# 684   여의대방로20길         0            1               4
#
# [685 rows x 4 columns]

# %% [markdown]
# # 음식점

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\음식점.csv",encoding='euc-kr')
data1_df.head(5)
# Out:
#      업종명       인허가일자        업소명                      소재지(도로명)  \
# 0  일반음식점  1967-10-10  청기와뼈다귀해장국        서울특별시 동작구 흑석로 94 (흑석동)
# 1  일반음식점  1972-04-14        안동장     서울특별시 동작구 흑석로 105-1 (흑석동)
# 2  일반음식점  1974-11-14        영빈관  서울특별시 동작구 장승배기로19길 21 (노량진동)
# 3  일반음식점  1975-05-15      바다회센타  서울특별시 동작구 동작대로27길 20-7 (사당동)
# 4  일반음식점  1975-09-24     야채순대곱창  서울특별시 동작구 동작대로27길 16-7 (사당동)
#
#                     소재지(지번)   영업장면적         소재지전화         업태명
# 0    서울특별시 동작구 흑석동 223번지 1호  163.96   02-822-8060          한식
# 1   서울특별시 동작구 흑석동 184번지 18호  321.03   02-813-0572         중국식
# 2  서울특별시 동작구 노량진동 313번지 91호   29.93   02-813-3088         중국식
# 3   서울특별시 동작구 사당동 130번지 16호   71.41  02-0533-0594          일식
# 4   서울특별시 동작구 사당동 130번지 13호   23.19  02-3476-2259  정종/대포집/소주방

# %%
# 도로명주소 추출 후 칼럼 추출
data1_df = data1_df[['업종명','인허가일자','소재지(도로명)','업태명']]
data1_df[['a','b','도로명','c']]=data1_df['소재지(도로명)'].str.split(' ', n=3, expand=True)
data1_df=data1_df.drop(['a','b','c','소재지(도로명)'],axis=1,inplace=False)
data1_df=data1_df[['도로명','업종명','인허가일자']]

# Null 값인 행 삭제
data1_df['도로명'] = data1_df['도로명'].fillna(0)
data1_df=data1_df.drop(data1_df[data1_df['도로명']==0].index,axis=0,inplace=False)

# 오기된 도로명주소 행 삭제
for address in data1_df['도로명']:
    if address not in list(data_df['도로명'].values):
        data1_df = data1_df.drop(data1_df[data1_df['도로명']==address].index, inplace=False, axis=0)
        
data1_df=data1_df.reset_index()
data1_df=data1_df.drop(['index'],axis=1,inplace=False)

data1_df
# Out:
#            도로명    업종명       인허가일자
# 0          흑석로  일반음식점  1967-10-10
# 1          흑석로  일반음식점  1972-04-14
# 2     장승배기로19길  일반음식점  1974-11-14
# 3      동작대로27길  일반음식점  1975-05-15
# 4      동작대로27길  일반음식점  1975-09-24
# 5          양녕로  일반음식점  1975-06-17
# 6      서달로12가길  일반음식점  1976-02-16
# 7          현충로  일반음식점  1977-09-08
# 8       노량진로6길  일반음식점  1977-05-13
# 9        성대로1길  일반음식점  1978-10-30
# 10    여의대방로24길  일반음식점  1979-11-30
# 11      서달로14길  일반음식점  1979-07-03
# 12      등용로14길  일반음식점  1979-06-11
# 13      노량진로8길  일반음식점  1979-04-12
# 14      서달로12길  일반음식점  1980-09-10
# 15        동작대로  일반음식점  1980-10-23
# 16      흑석로13길  일반음식점  1980-03-15
# 17         상도로  일반음식점  1993-11-01
# 18      상도로15길  일반음식점  1980-04-24
# 19        국사봉길  일반음식점  1980-05-07
# 20         흑석로  일반음식점  1980-07-16
# 21      사당로30길  일반음식점  1980-11-05
# 22     노량진로14길  일반음식점  1981-03-27
# 23     서달로12가길  일반음식점  1981-09-07
# 24         대림로  일반음식점  1981-08-28
# 25    장승배기로27길  일반음식점  1981-10-06
# 26     동작대로23길  일반음식점  1982-05-14
# 27     서달로14나길  일반음식점  1982-05-26
# 28        시흥대로  일반음식점  1982-10-12
# 29     동작대로43길  일반음식점  1994-01-29
# ...        ...    ...         ...
# 4234  장승배기로10길  휴게음식점  2019-03-04
# 4235       상도로  휴게음식점  2019-03-05
# 4236       대림로  휴게음식점  2019-03-05
# 4237    동작대로3길  휴게음식점  2019-03-08
# 4238    보라매로5길  휴게음식점  2019-03-11
# 4239     여의대방로  휴게음식점  2019-03-13
# 4240       만양로  휴게음식점  2019-03-15
# 4241     성대로1길  휴게음식점  2019-03-15
# 4242    양녕로25길  휴게음식점  2019-03-15
# 4243     국사봉1길  휴게음식점  2019-03-18
# 4244       양녕로  휴게음식점  2019-03-19
# 4245       흑석로  휴게음식점  2019-03-21
# 4246       사당로  휴게음식점  2019-03-21
# 4247       흑석로  휴게음식점  2019-03-22
# 4248    상도로67길  휴게음식점  2019-03-22
# 4249       노들로  휴게음식점  2019-03-22
# 4250  장승배기로10길  휴게음식점  2019-03-26
# 4251   보라매로5가길  휴게음식점  2019-03-26
# 4252  여의대방로54길  휴게음식점  2019-03-28
# 4253    상도로34길  휴게음식점  2019-04-01
# 4254       사당로  휴게음식점  2019-04-01
# 4255  노량진로23가길  휴게음식점  2019-04-02
# 4256   만양로14다길  휴게음식점  2019-04-02
# 4257       상도로  휴게음식점  2019-04-04
# 4258    사당로13길  휴게음식점  2019-04-12
# 4259       사당로  휴게음식점  2019-04-12
# 4260     장승배기로  휴게음식점  2019-04-12
# 4261       만양로  휴게음식점  2019-04-12
# 4262   동작대로27길  휴게음식점  2019-04-15
# 4263   동작대로27길  휴게음식점  2019-04-15
#
# [4264 rows x 3 columns]

# %%
# 개수 세기
addresses_count={}
for address in list(data1_df['도로명']):
    try:
        addresses_count[address]+=1
    except:
        addresses_count[address]=1
print(addresses_count)
# Out:
# {'흑석로': 170, '장승배기로19길': 10, '동작대로27길': 80, '양녕로': 48, '서달로12가길': 14, '현충로': 51, '노량진로6길': 19, '성대로1길': 21, '여의대방로24길': 62, '서달로14길': 26, '등용로14길': 30, '노량진로8길': 41, '서달로12길': 10, '동작대로': 73, '흑석로13길': 3, '상도로': 292, '상도로15길': 44, '국사봉길': 22, '사당로30길': 68, '노량진로14길': 17, '대림로': 34, '장승배기로27길': 8, '동작대로23길': 18, '서달로14나길': 17, '시흥대로': 28, '동작대로43길': 2, '동작대로7길': 99, '장승배기로10길': 30, '사당로': 199, '사당로16길': 42, '상도로61가길': 4, '동작대로27가길': 59, '여의대방로': 67, '흑석로9길': 22, '흑석로13가길': 11, '만양로2길': 2, '장승배기로': 114, '만양로': 139, '노량진로': 172, '동작대로1길': 37, '신대방길': 45, '노들로': 39, '보라매로': 53, '노량진로16길': 45, '만양로14길': 48, '상도로67길': 15, '국사봉1길': 53, '상도로30길': 26, '등용로': 54, '만양로16길': 11, '상도로62길': 14, '성대로2길': 14, '신대방11길': 5, '장승배기로10가길': 3, '흑석로8길': 12, '상도로37길': 32, '노량진로12길': 17, '서달로10길': 15, '상도로26길': 11, '상도로63길': 5, '상도로22길': 20, '사당로16가길': 26, '여의대방로22길': 22, '상도로61길': 41, '성대로': 32, '만양로14가길': 30, '만양로18길': 17, '노량진로14가길': 17, '흑석로6가길': 1, '동작대로29가길': 21, '동작대로31길': 10, '신대방18길': 1, '흑석로13나길': 2, '흑석로13마길': 11, '서달로15길': 22, '여의대방로26길': 3, '솔밭로': 6, '동작대로29길': 38, '상도로19길': 8, '동작대로25길': 56, '양녕로26길': 19, '여의대방로24나길': 2, '노들로2길': 1, '신대방2길': 12, '동작대로27다길': 36, '상도로34길': 13, '장승배기로21길': 1, '노량진로10길': 7, '동작대로27나길': 15, '동작대로3길': 32, '여의대방로24가길': 16, '사
25마길': 1, '상도로33길': 1, '동작대로35가길': 2, '상도로45길': 4, '서달로14라길': 2, '성대로12길': 2, '사당로12길': 6, '동작대로9다길': 1, '성대로10길': 3, '동작대로9가길': 1, '서달로8가길': 3, '사당로2차길': 7, '상도로38길': 3, '남부순환로259길': 3, '서달로14사길': 2, '남부순환로271가길': 1, '사당로2길': 1, '장승배기로11가길': 6, '국사봉5길': 1, '사당로22가길': 1, '양녕로20길': 1, '동작대로35다길': 1, '사당로26가길': 1, '등용로12나길': 1, '양녕로29길': 3, '동작대로33나길': 1, '장승배기로24길': 1, '상도로47바길': 1, '상도로38다길': 1, '상도로47가길': 2, '대방동15길': 2, '서달로14다길': 1, '장승배기로15길': 1, '매봉로2길': 1, '성대로16길': 1, '남부순환로263길': 1, '성대로37길': 1, '상도로22나길': 2, '노량진로30길': 1, '여의대방로46길': 2, '여의대방로62길': 1, '여의대방로22바길': 1, '동작대로39가길': 1, '장승배기로20길': 1, '상도로13길': 2, '보라매로19길': 2, '사당로16다길': 2, '상도로22가길': 1, '상도로49길': 1, '국사봉7길': 2, '보라매로7가길': 1, '사당로9나길': 1, '상도로60가길': 1, '사당로16바길': 1, '남부순환로255다길': 1, '만양로6길': 1, '사당로22나길': 1, '남부순환로255가길': 1, ' ...

# %%
data2_df=pd.DataFrame.from_records([addresses_count])
data2_df=data2_df.transpose().reset_index()
data2_df.rename(columns={'index': '도로명', 0: '음식점 개수'}, inplace=True)

# 값이 1인 데이터가 너무 많아서 업종명이랑 인허가일자도 제거..

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')
data_df['음식점 개수'] = data_df['음식점 개수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수  담배소매인 지정 업소 개수  음식점 개수
# 0        남부순환로         0            0               6      15
# 1         동작대로         2           11              15      73
# 2         시흥대로         0            0               6      28
# 3        올림픽대로         0            0               0       0
# 4         보라매로         2            8               8      53
# 5          솔밭로         4           12               2       6
# 6          양녕로         9           36               5      48
# 7          노들로         0           12               5      39
# 8          대림로         1            3               5      34
# 9        여의대방로         6           21              11      67
# 10         등용로         3           12              11      54
# 11         만양로         8           31              18     139
# 12         매봉로         3           11               7      16
# 13         사당로         3           17              24     199
# 14         상도로        10           43              58     292
# 15         서달로         4           28               7      35
# 16         성대로        14           49               4      32
# 17       장승배기로        11           39              22     114
# 18         현충로         3           14              14      51
# 19         흑석로         4           17              13     170
# 20        노량진로         6           26              38     172
# 21       흑석한강로         1            3               2       6
# 22      강남초등2길         0            0               0       0
# 23      강남초등4길         0            0               0       0
# 24      강남초등6길         0            0               0       0
# 25      강남초등8길         0            0               0       1
# 26       강남초등길         2            8               0       2
# 27      관악로30길         0            0               0       0
# 28      국사봉10길         3           11               1       1
# 29      국사봉12길         0            1               0       0
# ..         ...       ...          ...             ...     ...
# 655    흑석로10라길         0            0               0       0
# 656    흑석로10마길         0            0               0       0
# 657     흑석로11길         1            4               0       3
# 658    흑석로13가길         0            0               0      11
# 659     흑석로13길         1            3               0       3
# 660    흑석로13나길         0            0               0       2
# 661    흑석로13다길         0            0               0       0
# 662    흑석로13라길         0            0               0       0
# 663    흑석로13마길         1            2               0      11
# 664    흑석로13바길         0            0               0       0
# 665    흑석로15가길         0            0               0       0
# 666     흑석로15길         0            0               0       0
# 667    흑석로15나길         0            0               0       1
# 668     흑석로17길         0            0               0       0
# 669     흑석로3가길         0            0               0       0
# 670      흑석로3길         3            9               1       0
# 671      흑석로5길         3            8               1       0
# 672     흑석로6가길         0            0               1       1
# 673      흑석로6길         2            5               1       6
# 674     흑석로6나길         0            0               0       0
# 675      흑석로7길         1            4               1       6
# 676      흑석로8길         0            0               0      12
# 677      흑석로9길         3           12               1      22
# 678    노량진로23길         0            0               0       0
# 679   동작대로39가길         2            7               1       1
# 680  여의대방로24아길         0            0               0       0
# 681     보라매로3길         0            0               1      17
# 682     보라매로5길         0            1               5      64
# 683     보라매로7길         0            0               0       0
# 684   여의대방로20길         0            1               4       3
#
# [685 rows x 5 columns]

# %%
# Null 값이랑 오기된 주소 행 삭제하고 인덱스 갱신해주고 개수 세주고 피처 만들어주는 함수
def preprocessing(data1_df):
    data1_df['도로명'] = data1_df['도로명'].fillna(0)
    data1_df=data1_df.drop(data1_df[data1_df['도로명']==0].index,axis=0,inplace=False)
    
    for address in data1_df['도로명']:
        if address not in list(data_df['도로명'].values):
            data1_df = data1_df.drop(data1_df[data1_df['도로명']==address].index, inplace=False, axis=0)
        
    data1_df=data1_df.reset_index()
    data1_df=data1_df.drop(['index'],axis=1,inplace=False)
    print(data1_df)
    
    addresses_count={}
    for address in list(data1_df['도로명']):
        try:
            addresses_count[address]+=1
        except:
            addresses_count[address]=1
    print(addresses_count)
    
    data2_df=pd.DataFrame.from_records([addresses_count])
    data2_df=data2_df.transpose().reset_index()
    data2_df.rename(columns={'index': '도로명', 0: '피처'}, inplace=True)
    
    return data2_df

# %% [markdown]
# # 보안등

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\보안등.csv",encoding='euc-kr')
data1_df.head(5)
# Out:
#      보안등위치명  설치개수                소재지도로명주소                소재지지번주소         위도  \
# 0      노1동1     1      서울특별시 동작구 장승배기로128   서울특별시 동작구 노량진동 231-4  37.508638
# 1  노1동579-1     1     서울특별시 동작구 만양로 102-8   서울특별시 동작구 노량진동 118-7  37.512235
# 2  노1동444-1     1  서울특별시 동작구 노량진로26길 51-2     서울특별시 동작구 본동 51-19  37.510417
# 3  노1동444-2     1  서울특별시 동작구 노량진로26길 51-8     서울특별시 동작구 본동 51-15  37.510655
# 4  노1동268-2     1   서울특별시 동작구 노량진으로 194-4  서울특별시 동작구 노량진동 146-12  37.512874
#
#            경도    설치년도 설치형태     관리기관전화번호       관리기관명     데이터기준일자
# 0  126.940565  2011.0  한전주  02-820-1408  서울특별시 동작구청  2019-05-22
# 1  126.944280  2012.0  NaN  02-820-1408  서울특별시 동작구청  2019-05-22
# 2  126.955590  2011.0  NaN  02-820-1408  서울특별시 동작구청  2019-05-22
# 3  126.955581  2011.0  NaN  02-820-1408  서울특별시 동작구청  2019-05-22
# 4  126.947257  2011.0  NaN  02-820-1408  서울특별시 동작구청  2019-05-22

# %%
data1_df = data1_df[['소재지도로명주소']]
data1_df[['a','b','도로명','c']]=data1_df['소재지도로명주소'].str.split(' ', n=3, expand=True)
data1_df=data1_df.drop(['a','b','c','소재지도로명주소'],axis=1,inplace=False)

# %%
data1_df=data1_df[['도로명']]
data2_df= preprocessing(data1_df)
# Out:
#             도로명
# 0           만양로
# 1       노량진로26길
# 2       노량진로26길
# 3      장승배기로20길
# 4      장승배기로22길
# 5      장승배기로22길
# 6      장승배기로22길
# 7      장승배기로22길
# 8      장승배기로22길
# 9      장승배기로22길
# 10     장승배기로22길
# 11     장승배기로22길
# 12     장승배기로22길
# 13    장승배기로20다길
# 14    장승배기로20다길
# 15    장승배기로20다길
# 16     장승배기로24길
# 17     장승배기로24길
# 18     장승배기로24길
# 19    장승배기로24가길
# 20    장승배기로24가길
# 21    장승배기로24가길
# 22    장승배기로24나길
# 23    장승배기로24나길
# 24    장승배기로24나길
# 25    장승배기로24나길
# 26    장승배기로24나길
# 27    장승배기로24나길
# 28    장승배기로24나길
# 29     장승배기로24길
# ...         ...
# 8471     흑석로6나길
# 8472      흑석로6길
# 8473      흑석로6길
# 8474      흑석로6길
# 8475      흑석로6길
# 8476      흑석로6길
# 8477      흑석로6길
# 8478      흑석로6길
# 8479     흑석로6가길
# 8480     흑석로6가길
# 8481     흑석로6가길
# 8482     흑석로6가길
# 8483     흑석로6가길
# 8484     흑석로6가길
# 8485     흑석로6가길
# 8486      흑석로6길
# 8487      흑석로9길
# 8488      흑석로9길
# 8489      흑석로7길
# 8490      흑석로3길
# 8491      흑석로9길
# 8492      흑석로5길
# 8493      흑석로9길
# 8494      흑석로9길
# 8495      흑석로3길
# 8496      흑석로9길
# 8497      흑석로9길
# 8498      흑석로9길
# 8499      흑석로9길
# 8500      서달로2길
#
# [8501 rows x 1 columns]
# {'만양로': 34, '노량진로26길': 45, '장승배기로20길': 14, '장승배기로22길': 33, '장승배기로20다길': 5, '장승배기로24길': 25, '장승배기로24가길': 6, '장승배기로24나길': 7, '장승배기로20라길': 6, '장승배기로16길': 27, '노량진로14길': 16, '장승배기로28길': 14, '장승배기로26길': 21, '장승배기로': 42, '장승배기로30길': 5, '노량진로16길': 13, '노량진로14다길': 2, '노량진로14나길': 5, '만양로15길': 6, '만양로16길': 9, '만양로14가길': 8, '만양로18길': 7, '만양로14나길': 4, '만양로14길': 26, '만양로14다길': 6, '만양로14라길': 11, '만양로14마길': 10, '만양로12가길': 25, '노량진로20길': 2, '노량진로18길': 3, '노량진로22길': 13, '매봉로': 35, '만양로8길': 29, '만양로6길': 8, '만양로10길': 3, '만양로12길': 7, '만양로13길': 12, '장승배기로18길': 12, '만양로13가길': 10, '만양로11길': 9, '노량진로28길': 29, '노량진로8길': 13, '노량진로32길': 36, '노들로2길': 17, '노량진로30길': 11, '노량진로30가길':
': 4, '사당로22나길': 17, '동작대로11가길': 5, '동작대로11나길': 2, '사당로20라길': 12, '사당로20아길': 5, '사당로20바길': 10, '남부순환로269길': 25, '남부순환로265길': 26, '남부순환로257가길': 20, '남부순환로267가길': 3, '남부순환로265가길': 5, '남부순환로263길': 5, '남부순환로265나길': 3, '남부순환로257길': 15, '남부순환로261길': 10, '남부순환로259가길': 7, '남부순환로259길': 6, '남부순환로255길': 51, '남부순환로255나길': 5, '남부순환로255가길': 8, '남부순환로255다길': 9, '남부순환로271길': 9, '남부순환로267길': 3, '남부순환로267나길': 2, '동작대로29길': 84, '동작대로27길': 16, '동작대로27가길': 14, '동작대로27나길': 3, '동작대로25길': 15, '동작대로27다길': 14, '사당로29가길': 20, '동작대로27바길': 3, '동작대로27라길': 4, '동작대로27마길': 6, '사당로29길': 37, '동작대로29가길': 7, '동작대로31길': 21, '동작대로33길': 42, '동작대로33가길': 8, '동작대로33나길': 5, '동작대로33다길': 5, '동작대로35길': 50, '동작대로29나길': 11, '현충로': 14, '동작대로29다길': 4, '동작대로29라길': 5, '동작대로29마길': 3, '동작대로29바길': 3, '동작대로33라길': 7, '동작대로33마길': 16, '동작대로35가길': 26, '동작대로33바길': 13, '동작대로37길': 5, '동작대로35사길': 8, '동작대로35차길': 9, '동작대로35아길': 10, '동작대로35자길': 1, '동작대로35바길': 5, '동작대로39길': 30, '동작대로41길': 17, '동작대로43길': 9, '동작대로39가길': 24, '동작대로35마길': 7, '동작대로35라길': 2, '동작대로35다길': 9, '동작대로35나길': 4, '사당로23길': 139, '사당로27길': 81, '사당로17길': 16, '사당로17가길': 3, '사당로17나길': 5, '사당로17다길': 4, '사당로13길': 30, '사당로17라길': 4, '사당로9라길': 12, '사당로9다길': 7, '사당로9길': 14, '사당로9나길': 7, '사당로9가길': 18, '사당로23바길': 6, '사당로23사길': 18, '사당로23아길': 15, '사당로23나길': 5, '사당로29다길': 31, '사당로29라길': 10, '사당로29나길': 6, '사당로27가길': 5, '사당로25길': 8, '사당로25가길': 2, '사당로23가길': 2, '사당로14가길': 9, ...

# %%
data2_df.rename(columns={'피처': '보안등 개수'}, inplace=True)
data2_df
# Out:
#             도로명  보안등 개수
# 0        강남초등2길       2
# 1        강남초등4길       4
# 2        강남초등6길       5
# 3        강남초등8길       3
# 4         강남초등길      10
# 5        국사봉10길      34
# 6        국사봉12길       9
# 7        국사봉14길       6
# 8        국사봉16길      11
# 9        국사봉18길       2
# 10       국사봉1가길       5
# 11        국사봉1길      85
# 12       국사봉1나길      12
# 13       국사봉1다길       3
# 14       국사봉1라길       7
# 15       국사봉2가길       4
# 16        국사봉2길      12
# 17       국사봉2나길      12
# 18       국사봉2다길       4
# 19       국사봉2라길       4
# 20       국사봉2마길       2
# 21       국사봉2바길       8
# 22        국사봉3길       9
# 23        국사봉5길       6
# 24        국사봉6길      21
# 25        국사봉7길       3
# 26        국사봉8길      21
# 27         국사봉길      73
# 28   남부순환로255가길       8
# 29    남부순환로255길      51
# ..          ...     ...
# 618      현충로22길      12
# 619     현충로24가길       3
# 620      현충로24길       6
# 621      현충로2가길       1
# 622       현충로2길       1
# 623      현충로4나길       1
# 624       현충로6길       3
# 625       현충로8길       4
# 626         흑석로      22
# 627     흑석로10가길       3
# 628      흑석로10길      15
# 629     흑석로10나길       3
# 630     흑석로10다길       3
# 631     흑석로10라길       4
# 632     흑석로10마길       2
# 633      흑석로11길       7
# 634     흑석로13가길      10
# 635      흑석로13길      14
# 636     흑석로13다길       2
# 637     흑석로13마길      17
# 638     흑석로13바길      10
# 639      흑석로3가길       7
# 640       흑석로3길      37
# 641       흑석로5길      38
# 642      흑석로6가길       8
# 643       흑석로6길      15
# 644      흑석로6나길      11
# 645       흑석로7길      16
# 646       흑석로8길       6
# 647       흑석로9길      30
#
# [648 rows x 2 columns]

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')
data_df['보안등 개수']= data_df['보안등 개수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수  담배소매인 지정 업소 개수  음식점 개수  보안등 개수
# 0        남부순환로         0            0               6      15       0
# 1         동작대로         2           11              15      73      14
# 2         시흥대로         0            0               6      28      10
# 3        올림픽대로         0            0               0       0       0
# 4         보라매로         2            8               8      53      15
# 5          솔밭로         4           12               2       6      14
# 6          양녕로         9           36               5      48      25
# 7          노들로         0           12               5      39       0
# 8          대림로         1            3               5      34       5
# 9        여의대방로         6           21              11      67      29
# 10         등용로         3           12              11      54      50
# 11         만양로         8           31              18     139      34
# 12         매봉로         3           11               7      16      35
# 13         사당로         3           17              24     199      69
# 14         상도로        10           43              58     292      93
# 15         서달로         4           28               7      35      33
# 16         성대로        14           49               4      32      45
# 17       장승배기로        11           39              22     114      42
# 18         현충로         3           14              14      51      14
# 19         흑석로         4           17              13     170      22
# 20        노량진로         6           26              38     172       9
# 21       흑석한강로         1            3               2       6       0
# 22      강남초등2길         0            0               0       0       2
# 23      강남초등4길         0            0               0       0       4
# 24      강남초등6길         0            0               0       0       5
# 25      강남초등8길         0            0               0       1       3
# 26       강남초등길         2            8               0       2      10
# 27      관악로30길         0            0               0       0       0
# 28      국사봉10길         3           11               1       1      34
# 29      국사봉12길         0            1               0       0       9
# ..         ...       ...          ...             ...     ...     ...
# 655    흑석로10라길         0            0               0       0       4
# 656    흑석로10마길         0            0               0       0       2
# 657     흑석로11길         1            4               0       3       7
# 658    흑석로13가길         0            0               0      11      10
# 659     흑석로13길         1            3               0       3      14
# 660    흑석로13나길         0            0               0       2       0
# 661    흑석로13다길         0            0               0       0       2
# 662    흑석로13라길         0            0               0       0       0
# 663    흑석로13마길         1            2               0      11      17
# 664    흑석로13바길         0            0               0       0      10
# 665    흑석로15가길         0            0               0       0       0
# 666     흑석로15길         0            0               0       0       0
# 667    흑석로15나길         0            0               0       1       0
# 668     흑석로17길         0            0               0       0       0
# 669     흑석로3가길         0            0               0       0       7
# 670      흑석로3길         3            9               1       0      37
# 671      흑석로5길         3            8               1       0      38
# 672     흑석로6가길         0            0               1       1       8
# 673      흑석로6길         2            5               1       6      15
# 674     흑석로6나길         0            0               0       0      11
# 675      흑석로7길         1            4               1       6      16
# 676      흑석로8길         0            0               0      12       6
# 677      흑석로9길         3           12               1      22      30
# 678    노량진로23길         0            0               0       0       0
# 679   동작대로39가길         2            7               1       1      24
# 680  여의대방로24아길         0            0               0       0       0
# 681     보라매로3길         0            0               1      17       0
# 682     보라매로5길         0            1               5      64       5
# 683     보라매로7길         0            0               0       0       1
# 684   여의대방로20길         0            1               4       3       0
#
# [685 rows x 6 columns]

# %% [markdown]
# # 아파트

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\아파트.csv",encoding='euc-kr')
data1_df.head(5)
# Out:
#    연번     아파트명    행정동   번지         도로명주소       층수  동수    총호수  난방방식         대지  \
# 0   1    노량진우성  노량진1동  323      만양로8길 50  2/17~18   7    901  중앙가스  36,371.00
# 1   2    노량진삼익  노량진1동  330        만양로 84       19   1    175  개별가스   6,224.00
# 2   3  신동아리버파크  노량진1동  325        만양로 19  2/18~28  10  2,621  중앙가스  78,989.60
# 3   4  노량진쌍용예가  노량진1동  332  장승배기로16길 134       15   5    299  개별난방  15,603.10
# 4   5     형인한강  노량진1동  331        만양로 36      NaN   1     73  개별가스   2,358.70
#
#           연면적    주차장        사업승인        준공일자 사업방법    관리사무소전화번호
# 0   27,659.79    921  1990-06-16  1997-12-16  재개발  02-823-4532
# 1   34,982.89    171  1995-06-21  2001-07-11  재건축  02-815-6850
# 2  307,831.06  2,462  1994-08-04  2001-02-15  재개발  02-812-0322
# 3   49,333.84    333  2004-06-04  2010-08-26  재개발  02-813-7510
# 4    8,241.00     75  2000-03-25  2001-08-06  재건축  02-814-1925

# %%
data1_df = data1_df[['도로명주소','총호수']]
data1_df[['도로명','a']]=data1_df['도로명주소'].str.split(' ', n=1, expand=True)
data1_df=data1_df.drop(['도로명주소','a'],axis=1,inplace=False)
data1_df=data1_df[['도로명','총호수']]
data1_df
# Out:
#            도로명    총호수
# 0        만양로8길    901
# 1          만양로    175
# 2          만양로  2,621
# 3     장승배기로16길    299
# 4          만양로     73
# 5     장승배기로18길     49
# 6          매봉로    123
# 7          매봉로    765
# 8      노량진로24길    161
# 9     노량진로23가길    306
# 10     노량진로32길    272
# 11         매봉로    381
# 12         매봉로    477
# 13     노량진로22길    176
# 14    노량진로23가길    523
# 15         양녕로     78
# 16         상도로    544
# 17         상도로     69
# 18         상도로    405
# 19         상도로    682
# 20      사당로24길     38
# 21      상도로60길    279
# 22       사당로2길    194
# 23      상도로55길    431
# 24      상도로53길  1,656
# 25         상도로  1,559
# 26         상도로    882
# 27      상도로53길    953
# 28     상도로47바길     80
# 29      상도로55길     91
# ..         ...    ...
# 103   여의대방로44길    798
# 104   여의대방로62길     90
# 105     등용로14길    134
# 106   여의대방로62길    206
# 107       알마타길    278
# 108       알마타길    609
# 109       알마타길    100
# 110  여의대방로24다길    200
# 111   여의대방로62길    130
# 112   여의대방로54길    163
# 113      여의대방로  1,335
# 114      여의대방로    174
# 115      여의대방로    880
# 116   여의대방로10길    295
# 117       신대방길    427
# 118   여의대방로10길    734
# 119     신대방1나길    135
# 120   여의대방로10길    105
# 121  여의대방로22나길     60
# 122  여의대방로22아길    171
# 123   여의대방로10길    272
# 124       보라매로    108
# 125     보라매로5길    199
# 126   여의대방로22길    132
# 127   여의대방로10길    423
# 128     보라매로3길    256
# 129       보라매로    386
# 130        현충로   1073
# 131        서달로    545
# 132        상도로    893
#
# [133 rows x 2 columns]

# %%
for address in data1_df['도로명']:
    if address not in list(data_df['도로명'].values):
        data1_df = data1_df.drop(data1_df[data1_df['도로명']==address].index, inplace=False, axis=0)
        
data1_df=data1_df.reset_index()
data1_df=data1_df.drop(['index'],axis=1,inplace=False)

address_without=[]
for address in data1_df['총호수']:
    without=address.replace(',','')
    address_without.append(without)
    
data1_df['총_호수'] = address_without
data1_df= data1_df.drop('총호수',axis=1,inplace=False)
data1_df
# Out:
#            도로명  총_호수
# 0        만양로8길   901
# 1          만양로   175
# 2          만양로  2621
# 3     장승배기로16길   299
# 4          만양로    73
# 5     장승배기로18길    49
# 6          매봉로   123
# 7          매봉로   765
# 8      노량진로24길   161
# 9     노량진로23가길   306
# 10     노량진로32길   272
# 11         매봉로   381
# 12         매봉로   477
# 13     노량진로22길   176
# 14    노량진로23가길   523
# 15         양녕로    78
# 16         상도로   544
# 17         상도로    69
# 18         상도로   405
# 19         상도로   682
# 20      사당로24길    38
# 21      상도로60길   279
# 22       사당로2길   194
# 23      상도로55길   431
# 24      상도로53길  1656
# 25         상도로  1559
# 26         상도로   882
# 27      상도로53길   953
# 28     상도로47바길    80
# 29      상도로55길    91
# ..         ...   ...
# 103   여의대방로44길   798
# 104   여의대방로62길    90
# 105     등용로14길   134
# 106   여의대방로62길   206
# 107       알마타길   278
# 108       알마타길   609
# 109       알마타길   100
# 110  여의대방로24다길   200
# 111   여의대방로62길   130
# 112   여의대방로54길   163
# 113      여의대방로  1335
# 114      여의대방로   174
# 115      여의대방로   880
# 116   여의대방로10길   295
# 117       신대방길   427
# 118   여의대방로10길   734
# 119     신대방1나길   135
# 120   여의대방로10길   105
# 121  여의대방로22나길    60
# 122  여의대방로22아길   171
# 123   여의대방로10길   272
# 124       보라매로   108
# 125     보라매로5길   199
# 126   여의대방로22길   132
# 127   여의대방로10길   423
# 128     보라매로3길   256
# 129       보라매로   386
# 130        현충로  1073
# 131        서달로   545
# 132        상도로   893
#
# [133 rows x 2 columns]

# %%
addresses=[]
add=[]
for index, address in enumerate(list(data1_df['도로명'])):
    address=(address+str(' '))* int(data1_df.ix[index, 1])
    addresses.append(address)
for element in addresses:
    dd=str(element).split(sep=' ')
    add.extend(dd)
add
# Out:
# C:\Users\intae\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# ['만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '만양로8길',
#  '',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  '만양로',
#  ...]

# %%
addresses_count={}
for address in add:
    try:
        addresses_count[address]+=1
    except:
        addresses_count[address]=1
        
print(addresses_count)
# Out:
# {'만양로8길': 901, '': 133, '만양로': 4245, '장승배기로16길': 299, '장승배기로18길': 49, '매봉로': 1746, '노량진로24길': 161, '노량진로23가길': 829, '노량진로32길': 272, '노량진로22길': 176, '양녕로': 219, '상도로': 5690, '사당로24길': 38, '상도로60길': 279, '사당로2길': 377, '상도로55길': 522, '상도로53길': 2609, '상도로47바길': 80, '등용로': 681, '장승배기로': 400, '장승배기로4길': 1122, '장승배기로10길': 138, '상도로31길': 415, '상도로34길': 162, '상도로30길': 772, '장승배기로11가길': 471, '국사봉길': 241, '양녕로26길': 130, '양녕로23길': 272, '양녕로26나길': 61, '서달로': 1765, '서달로1길': 423, '현충로': 2693, '현충로10길': 90, '서달로2길': 346, '흑석한강로': 1518, '사당로20길': 140, '사당로26길': 60, '동작대로29길': 4971, '동작대로39가길': 276, '동작대로43길': 44, '동작대로35아길': 113, '동작대로45길': 178, '동작대로39길': 680, '사당로17길': 1498, '사당로27길': 1119, '사당로9가길': 416, '사당로': 120, '사당로23바길': 896, '사당로13길': 493, '사당로23길': 668, '남부순환로255길': 183, '사당로16아길': 140, '사당로20나길': 111, '사당로16길': 480, '사당로16다길': 296, '사당로2가길': 1061, '솔밭로': 63, '관악로30길': 40, '여의대방로44길': 3838, '노량진로': 514, '여의대방로62길': 426, '등용로14길': 134, '알마타길': 987, '여의대방로24다길': 200, '여의대방로54길': 163, '여의대방로': 2389, '여의대방로10길': 1829, '신대방길': 427, '신대방1나길': 135, '여의대방로22나길': 60, '여의대방로22아길': 171, '보라매로': 494, '보라매로5길': 199, '여의대방로22길': 132, '보라매로3길': 256}

# %%
data2_df=pd.DataFrame.from_records([addresses_count])
data2_df=data2_df.transpose().reset_index()
data2_df.rename(columns={'index': '도로명', 0: '아파트 세대 수'}, inplace=True)
data2_df=data2_df.drop(0, inplace=False)
data2_df
# Out:
#           도로명  아파트 세대 수
# 1      관악로30길        40
# 2        국사봉길       241
# 3   남부순환로255길       183
# 4        노량진로       514
# 5     노량진로22길       176
# 6    노량진로23가길       829
# 7     노량진로24길       161
# 8     노량진로32길       272
# 9     동작대로29길      4971
# 10   동작대로35아길       113
# 11   동작대로39가길       276
# 12    동작대로39길       680
# 13    동작대로43길        44
# 14    동작대로45길       178
# 15        등용로       681
# 16     등용로14길       134
# 17        만양로      4245
# 18      만양로8길       901
# 19        매봉로      1746
# 20       보라매로       494
# 21     보라매로3길       256
# 22     보라매로5길       199
# 23        사당로       120
# 24     사당로13길       493
# 25     사당로16길       480
# 26    사당로16다길       296
# 27    사당로16아길       140
# 28     사당로17길      1498
# 29     사당로20길       140
# 30    사당로20나길       111
# ..        ...       ...
# 46     상도로60길       279
# 47        서달로      1765
# 48      서달로1길       423
# 49      서달로2길       346
# 50        솔밭로        63
# 51     신대방1나길       135
# 52       신대방길       427
# 53       알마타길       987
# 54        양녕로       219
# 55     양녕로23길       272
# 56     양녕로26길       130
# 57    양녕로26나길        61
# 58      여의대방로      2389
# 59   여의대방로10길      1829
# 60   여의대방로22길       132
# 61  여의대방로22나길        60
# 62  여의대방로22아길       171
# 63  여의대방로24다길       200
# 64   여의대방로44길      3838
# 65   여의대방로54길       163
# 66   여의대방로62길       426
# 67      장승배기로       400
# 68   장승배기로10길       138
# 69  장승배기로11가길       471
# 70   장승배기로16길       299
# 71   장승배기로18길        49
# 72    장승배기로4길      1122
# 73        현충로      2693
# 74     현충로10길        90
# 75      흑석한강로      1518
#
# [75 rows x 2 columns]

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')
data_df['아파트 세대 수']= data_df['아파트 세대 수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수  담배소매인 지정 업소 개수  음식점 개수  보안등 개수  \
# 0        남부순환로         0            0               6      15       0
# 1         동작대로         2           11              15      73      14
# 2         시흥대로         0            0               6      28      10
# 3        올림픽대로         0            0               0       0       0
# 4         보라매로         2            8               8      53      15
# 5          솔밭로         4           12               2       6      14
# 6          양녕로         9           36               5      48      25
# 7          노들로         0           12               5      39       0
# 8          대림로         1            3               5      34       5
# 9        여의대방로         6           21              11      67      29
# 10         등용로         3           12              11      54      50
# 11         만양로         8           31              18     139      34
# 12         매봉로         3           11               7      16      35
# 13         사당로         3           17              24     199      69
# 14         상도로        10           43              58     292      93
# 15         서달로         4           28               7      35      33
# 16         성대로        14           49               4      32      45
# 17       장승배기로        11           39              22     114      42
# 18         현충로         3           14              14      51      14
# 19         흑석로         4           17              13     170      22
# 20        노량진로         6           26              38     172       9
# 21       흑석한강로         1            3               2       6       0
# 22      강남초등2길         0            0               0       0       2
# 23      강남초등4길         0            0               0       0       4
# 24      강남초등6길         0            0               0       0       5
# 25      강남초등8길         0            0               0       1       3
# 26       강남초등길         2            8               0       2      10
# 27      관악로30길         0            0               0       0       0
# 28      국사봉10길         3           11               1       1      34
# 29      국사봉12길         0            1               0       0       9
# ..         ...       ...          ...             ...     ...     ...
# 655    흑석로10라길         0            0               0       0       4
# 656    흑석로10마길         0            0               0       0       2
# 657     흑석로11길         1            4               0       3       7
# 658    흑석로13가길         0            0               0      11      10
# 659     흑석로13길         1            3               0       3      14
# 660    흑석로13나길         0            0               0       2       0
# 661    흑석로13다길         0            0               0       0       2
# 662    흑석로13라길         0            0               0       0       0
# 663    흑석로13마길         1            2               0      11      17
# 664    흑석로13바길         0            0               0       0      10
# 665    흑석로15가길         0            0               0       0       0
# 666     흑석로15길         0            0               0       0       0
# 667    흑석로15나길         0            0               0       1       0
# 668     흑석로17길         0            0               0       0       0
# 669     흑석로3가길         0            0               0       0       7
# 670      흑석로3길         3            9               1       0      37
# 671      흑석로5길         3            8               1       0      38
# 672     흑석로6가길         0            0               1       1       8
# 673      흑석로6길         2            5               1       6      15
# 674     흑석로6나길         0            0               0       0      11
# 675      흑석로7길         1            4               1       6      16
# 676      흑석로8길         0            0               0      12       6
# 677      흑석로9길         3           12               1      22      30
# 678    노량진로23길         0            0               0       0       0
# 679   동작대로39가길         2            7               1       1      24
# 680  여의대방로24아길         0            0               0       0       0
# 681     보라매로3길         0            0               1      17       0
# 682     보라매로5길         0            1               5      64       5
# 683     보라매로7길         0            0               0       0       1
# 684   여의대방로20길         0            1               4       3       0
#
#      아파트 세대 수
# 0           0
# 1           0
# 2           0
# 3           0
# 4         494
# 5          63
# 6         219
# 7           0
# 8           0
# 9        2389
# 10        681
# 11       4245
# 12       1746
# 13        120
# 14       5690
# 15       1765
# 16          0
# 17        400
# 18       2693
# 19          0
# 20        514
# 21       1518
# 22          0
# 23          0
# 24          0
# 25          0
# 26          0
# 27         40
# 28          0
# 29          0
# ..        ...
# 655         0
# 656         0
# 657         0
# 658         0
# 659         0
# 660         0
# 661         0
# 662         0
# 663         0
# 664         0
# 665         0
# 666         0
# 667         0
# 668         0
# 669         0
# 670         0
# 671         0
# 672         0
# 673         0
# 674         0
# 675         0
# 676         0
# 677         0
# 678         0
# 679       276
# 680         0
# 681       256
# 682       199
# 683         0
# 684         0
#
# [685 rows x 7 columns]

# %% [markdown]
# # 과속방지턱

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\과속방지턱.csv",encoding='cp949')
data1_df.head(5)
# Out:
#    연번  시군구    시설명        위치 보차도구분유무    설치년도 설치종류  폭(m)  높이(m)  연장(m)  면적(㎡)  \
# 0   1  동작구  과속방지턱  강남초등6길 2       유  2010이전  원호형   3.6   0.08    4.7  16.92
# 1   2  동작구  과속방지턱  강남초등길 12       유  2010이전  가상형   3.6    NaN    4.7  16.92
# 2   3  동작구  과속방지턱  강남초등길 12       무    2015  가상형   3.6    NaN    4.0  14.40
# 3   4  동작구  과속방지턱  강남초등길 14       무    2015  원호형   3.6   0.10    4.6  16.56
# 4   5  동작구  과속방지턱  강남초등길 22       유    2016  원호형   3.6   0.10    5.5  19.80
#
#    Unnamed: 11 Unnamed: 12
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN

# %%
data1_df = data1_df[['위치']]
data1_df[['도로명','a']]=data1_df['위치'].str.split(' ', n=1, expand=True)
data1_df=data1_df.drop(['위치','a'],axis=1,inplace=False)
data1_df
# Out:
#                      도로명
# 0                 강남초등6길
# 1                  강남초등길
# 2                  강남초등길
# 3                  강남초등길
# 4                  강남초등길
# 5                  강남초등길
# 6                  강남초등길
# 7                 국사봉10길
# 8                  국사봉1길
# 9                  국사봉1길
# 10                 국사봉1길
# 11                 국사봉1길
# 12                 국사봉1길
# 13                 국사봉1길
# 14                 국사봉1길
# 15                 국사봉1길
# 16                 국사봉1길
# 17                 국사봉1길
# 18                국사봉2라길
# 19                 국사봉5길
# 20                 국사봉5길
# 21                 국사봉5길
# 22                 국사봉6길
# 23                 국사봉7길
# 24                  국사봉길
# 25                  국사봉길
# 26                  국사봉길
# 27                  국사봉길
# 28                  국사봉길
# 29                  국사봉길
# ...                  ...
# 1080                 사당로
# 1081               여의대방로
# 1082             아크로리버하임
# 1083             아크로리버하임
# 1084             아크로리버하임
# 1085           흑석동186-13
# 1086             흑석로13마길
# 1087              양녕로20길
# 1088          국사봉길119-20
# 1089             상도로41마길
# 1090              강남초등8길
# 1091           상도동265-36
# 1092     국사봉1길(구립연꽃어린이집)
# 1093       성대로6가길(은혜유치원)
# 1094      장승배기로5길(성모유치원)
# 1095              양녕로23길
# 1096              상도로34길
# 1097   상도로50길(상도센트럴파크아파트
# 1098              사당로12길
# 1099             사당로14가길
# 1100  동작대로29길(신동아아파트401동
# 1101     상도로38길(상도중앙하이츠)
# 1102     상도로38길(상도중앙하이츠)
# 1103     상도로38길(상도중앙하이츠)
# 1104     상도로38길(상도중앙하이츠)
# 1105        남부순환로257가길49
# 1106       여의대방로36길100-1
# 1107            여의대방로36길
# 1108            사당로20길79
# 1109         국사봉1길235-11
#
# [1110 rows x 1 columns]

# %%
data2_df= preprocessing(data1_df)
data2_df.rename(columns={'피처': '과속방지턱 개수'}, inplace=True)
data2_df
# Out:
#            도로명
# 0       강남초등6길
# 1        강남초등길
# 2        강남초등길
# 3        강남초등길
# 4        강남초등길
# 5        강남초등길
# 6        강남초등길
# 7       국사봉10길
# 8        국사봉1길
# 9        국사봉1길
# 10       국사봉1길
# 11       국사봉1길
# 12       국사봉1길
# 13       국사봉1길
# 14       국사봉1길
# 15       국사봉1길
# 16       국사봉1길
# 17       국사봉1길
# 18      국사봉2라길
# 19       국사봉5길
# 20       국사봉5길
# 21       국사봉5길
# 22       국사봉6길
# 23       국사봉7길
# 24        국사봉길
# 25        국사봉길
# 26        국사봉길
# 27        국사봉길
# 28        국사봉길
# 29        국사봉길
# ...        ...
# 1044   동작대로19길
# 1045    사당로28길
# 1046    사당로28길
# 1047    사당로26길
# 1048   동작대로11길
# 1049   사당로28가길
# 1050   동작대로9가길
# 1051    사당로26길
# 1052    사당로26길
# 1053    사당로26길
# 1054    사당로30길
# 1055    성대로16길
# 1056    성대로16길
# 1057     신대방2길
# 1058     신대방2길
# 1059    양녕로20길
# 1060    상도로62길
# 1061    양녕로20길
# 1062     여의대방로
# 1063       사당로
# 1064     여의대방로
# 1065   흑석로13마길
# 1066    양녕로20길
# 1067   상도로41마길
# 1068    강남초등8길
# 1069    양녕로23길
# 1070    상도로34길
# 1071    사당로12길
# 1072   사당로14가길
# 1073  여의대방로36길
#
# [1074 rows x 1 columns]
# {'강남초등6길': 1, '강남초등길': 6, '국사봉10길': 1, '국사봉1길': 10, '국사봉2라길': 1, '국사봉5길': 3, '국사봉6길': 1, '국사봉7길': 1, '국사봉길': 8, '남부순환로': 1, '남부순환로255길': 4, '남부순환로255다길': 3, '남부순환로257가길': 2, '남부순환로257길': 3, '남부순환로265길': 2, '남부순환로269길': 8, '남부순환로271가길': 1, '노량진로': 3, '노량진로10길': 3, '노량진로14길': 2, '노량진로23가길': 1, '노량진로24길': 2, '노량진로26길': 4, '노량진로30길': 2, '노량진로32길': 8, '노량진로6길': 4, '노량진로8길': 6, '대림로': 2, '대방동15길': 2, '대방동15다길': 2, '대방동1길': 10, '대방동23길': 3, '대방동27길': 10, '대방동2길': 1, '대방동3길': 1, '대방동길': 10, '동작대로': 3, '동작대로11길': 5, '동작대로13길': 7, '동작대로15길': 1, '동작대로17길': 5, '동작대로25길': 3,
신대방14길': 9, '신대방16길': 3, '신대방16나길': 1, '신대방1가길': 3, '신대방1길': 5, '신대방2길': 4, '신대방3길': 4, '신대방길': 5, '알마타길': 13, '양녕로': 4, '양녕로20길': 5, '양녕로22나길': 1, '양녕로23길': 3, '양녕로25길': 3, '양녕로25사길': 2, '양녕로26길': 1, '양녕로27길': 3, '양녕로28길': 1, '양녕로29길': 1, '양녕로36길': 1, '여의대방로': 3, '여의대방로10길': 10, '여의대방로16길': 2, '여의대방로22길': 8, '여의대방로22나길': 7, '여의대방로22사길': 2, '여의대방로22아길': 4, '여의대방로22차길': 2, '여의대방로22카길': 2, '여의대방로24길': 11, '여의대방로24다길': 1, '여의대방로24라길': 1, '여의대방로24마길': 2, '여의대방로26길': 1, '여의대방로36길': 9, '여의대방로44길': 10, '여의대방로46길': 7, '여의대방로54길': 4, '여의대방로62길': 6, '장승배기로': 5, '장승배기로10가길': 6, '장승배기로10길': 18, '장승배기로15길': 2, '장승배기로16길': 12, '장승배기로17길': 1, '장승배기로19길': 3, '장승배기로19다길': 2, '장승배기로20길': 6, '장승배기로24길': 1, '장승배기로26길': 2, '장승배기로27길': 2, '장승배기로28길': 1, '장승배기로4길': 2, '장승배기로9길': 1, '현충로10길': 2, '현충로4길': 4, '현충로6길': 1, '현충로8길': 1, '흑석로': 8, '흑석로10길': 3, '흑석로13길': 4, '흑석로5길': 2, '흑석로6길': 3, '흑석로9길': 6, '흑석한강로': 9, '동작대로19길': 1, '사당로28가길': 1, '동작대로9가길': 1, '흑석로13마길': 1, '상도로41마길': 1, '강남초등8길': 1, '사당로14가길': 1}
#             도로명  과속방지턱 개수
# 0        강남초등6길         1
# 1        강남초등8길         1
# 2         강남초등길         6
# 3        국사봉10길         1
# 4         국사봉1길        10
# 5        국사봉2라길         1
# 6         국사봉5길         3
# 7         국사봉6길         1
# 8         국사봉7길         1
# 9          국사봉길         8
# 10        남부순환로         1
# 11    남부순환로255길         4
# 12   남부순환로255다길         3
# 13   남부순환로257가길         2
# 14    남부순환로257길         3
# 15    남부순환로265길         2
# 16    남부순환로269길         8
# 17   남부순환로271가길         1
# 18         노량진로         3
# 19      노량진로10길         3
# 20      노량진로14길         2
# 21     노량진로23가길         1
# 22      노량진로24길         2
# 23      노량진로26길         4
# 24      노량진로30길         2
# 25      노량진로32길         8
# 26       노량진로6길         4
# 27       노량진로8길         6
# 28          대림로         2
# 29       대방동15길         2
# ..          ...       ...
# 230    여의대방로46길         7
# 231    여의대방로54길         4
# 232    여의대방로62길         6
# 233       장승배기로         5
# 234   장승배기로10가길         6
# 235    장승배기로10길        18
# 236    장승배기로15길         2
# 237    장승배기로16길        12
# 238    장승배기로17길         1
# 239    장승배기로19길         3
# 240   장승배기로19다길         2
# 241    장승배기로20길         6
# 242    장승배기로24길         1
# 243    장승배기로26길         2
# 244    장승배기로27길         2
# 245    장승배기로28길         1
# 246     장승배기로4길         2
# 247     장승배기로9길         1
# 248      현충로10길         2
# 249       현충로4길         4
# 250       현충로6길         1
# 251       현충로8길         1
# 252         흑석로         8
# 253      흑석로10길         3
# 254      흑석로13길         4
# 255     흑석로13마길         1
# 256       흑석로5길         2
# 257       흑석로6길         3
# 258       흑석로9길         6
# 259       흑석한강로         9
#
# [260 rows x 2 columns]

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')
data_df['과속방지턱 개수']= data_df['과속방지턱 개수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수  담배소매인 지정 업소 개수  음식점 개수  보안등 개수  \
# 0        남부순환로         0            0               6      15       0
# 1         동작대로         2           11              15      73      14
# 2         시흥대로         0            0               6      28      10
# 3        올림픽대로         0            0               0       0       0
# 4         보라매로         2            8               8      53      15
# 5          솔밭로         4           12               2       6      14
# 6          양녕로         9           36               5      48      25
# 7          노들로         0           12               5      39       0
# 8          대림로         1            3               5      34       5
# 9        여의대방로         6           21              11      67      29
# 10         등용로         3           12              11      54      50
# 11         만양로         8           31              18     139      34
# 12         매봉로         3           11               7      16      35
# 13         사당로         3           17              24     199      69
# 14         상도로        10           43              58     292      93
# 15         서달로         4           28               7      35      33
# 16         성대로        14           49               4      32      45
# 17       장승배기로        11           39              22     114      42
# 18         현충로         3           14              14      51      14
# 19         흑석로         4           17              13     170      22
# 20        노량진로         6           26              38     172       9
# 21       흑석한강로         1            3               2       6       0
# 22      강남초등2길         0            0               0       0       2
# 23      강남초등4길         0            0               0       0       4
# 24      강남초등6길         0            0               0       0       5
# 25      강남초등8길         0            0               0       1       3
# 26       강남초등길         2            8               0       2      10
# 27      관악로30길         0            0               0       0       0
# 28      국사봉10길         3           11               1       1      34
# 29      국사봉12길         0            1               0       0       9
# ..         ...       ...          ...             ...     ...     ...
# 655    흑석로10라길         0            0               0       0       4
# 656    흑석로10마길         0            0               0       0       2
# 657     흑석로11길         1            4               0       3       7
# 658    흑석로13가길         0            0               0      11      10
# 659     흑석로13길         1            3               0       3      14
# 660    흑석로13나길         0            0               0       2       0
# 661    흑석로13다길         0            0               0       0       2
# 662    흑석로13라길         0            0               0       0       0
# 663    흑석로13마길         1            2               0      11      17
# 664    흑석로13바길         0            0               0       0      10
# 665    흑석로15가길         0            0               0       0       0
# 666     흑석로15길         0            0               0       0       0
# 667    흑석로15나길         0            0               0       1       0
# 668     흑석로17길         0            0               0       0       0
# 669     흑석로3가길         0            0               0       0       7
# 670      흑석로3길         3            9               1       0      37
# 671      흑석로5길         3            8               1       0      38
# 672     흑석로6가길         0            0               1       1       8
# 673      흑석로6길         2            5               1       6      15
# 674     흑석로6나길         0            0               0       0      11
# 675      흑석로7길         1            4               1       6      16
# 676      흑석로8길         0            0               0      12       6
# 677      흑석로9길         3           12               1      22      30
# 678    노량진로23길         0            0               0       0       0
# 679   동작대로39가길         2            7               1       1      24
# 680  여의대방로24아길         0            0               0       0       0
# 681     보라매로3길         0            0               1      17       0
# 682     보라매로5길         0            1               5      64       5
# 683     보라매로7길         0            0               0       0       1
# 684   여의대방로20길         0            1               4       3       0
#
#      아파트 세대 수  과속방지턱 개수
# 0           0         1
# 1           0         3
# 2           0         0
# 3           0         0
# 4         494         0
# 5          63         9
# 6         219         4
# 7           0         0
# 8           0         2
# 9        2389         3
# 10        681        23
# 11       4245        21
# 12       1746        20
# 13        120         6
# 14       5690        25
# 15       1765        14
# 16          0         8
# 17        400         5
# 18       2693         0
# 19          0         8
# 20        514         3
# 21       1518         9
# 22          0         0
# 23          0         0
# 24          0         1
# 25          0         1
# 26          0         6
# 27         40         0
# 28          0         1
# 29          0         0
# ..        ...       ...
# 655         0         0
# 656         0         0
# 657         0         0
# 658         0         0
# 659         0         4
# 660         0         0
# 661         0         0
# 662         0         0
# 663         0         1
# 664         0         0
# 665         0         0
# 666         0         0
# 667         0         0
# 668         0         0
# 669         0         0
# 670         0         0
# 671         0         2
# 672         0         0
# 673         0         3
# 674         0         0
# 675         0         0
# 676         0         0
# 677         0         6
# 678         0         0
# 679       276         1
# 680         0         0
# 681       256         1
# 682       199         9
# 683         0         1
# 684         0         0
#
# [685 rows x 8 columns]

# %% [markdown]
# # 금연구역

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\금연구역.csv",encoding='cp949')
data1_df.head(5)
# Out:
#            금연구역명 금연구역범위상세    시도명 시군구명      금연구역구분     금연구역지정근거명  금연구역면적  \
# 0          크레이지건       실내  서울특별시  동작구  100㎡미만 음식점  국민건강증진법 제 9조     NaN
# 1             만나       실내  서울특별시  동작구  100㎡미만 음식점  국민건강증진법 제 9조     NaN
# 2            아지트       실내  서울특별시  동작구  100㎡미만 음식점  국민건강증진법 제 9조     NaN
# 3  멕시카나치킨 앤 미스터큐       실내  서울특별시  동작구  100㎡미만 음식점  국민건강증진법 제 9조     NaN
# 4       큐(Q)치킨호프       실내  서울특별시  동작구  100㎡미만 음식점  국민건강증진법 제 9조     NaN
#
#     위반과태료     위반신고전화번호                           소재지도로명주소 소재지지번주소       관리기관명  \
# 0  100000  02-820-9437  서울특별시 동작구 동작대로27길 16-5 (사당동,(2층))     NaN  서울특별시 동작구청
# 1  100000  02-820-9437            서울특별시 동작구 현충로 119 (흑석동)     NaN  서울특별시 동작구청
# 2  100000  02-820-9437    서울특별시 동작구 동작대로27길 32 (사당동,(2층))     NaN  서울특별시 동작구청
# 3  100000  02-820-9437     서울특별시 동작구 여의대방로36길 100-1 (대방동)     NaN  서울특별시 동작구청
# 4  100000  02-820-9437      서울특별시 동작구 보라매로 93 (신대방동,외1필지)     NaN  서울특별시 동작구청
#
#          위도         경도     데이터기준일자
# 0  37.48777  126.98101  2019-05-15
# 1  37.50838  126.96699  2019-05-15
# 2  37.48762  126.98025  2019-05-15
# 3  37.50835  126.93154  2019-05-15
# 4  37.49779  126.92772  2019-05-15

# %%
data1_df = data1_df[['소재지도로명주소']]
data1_df[['a','b','도로명','c']]=data1_df['소재지도로명주소'].str.split(' ', n=3, expand=True)
data1_df=data1_df.drop(['소재지도로명주소','a','b','c'],axis=1,inplace=False)
data1_df
# Out:
#             도로명
# 0       동작대로27길
# 1           현충로
# 2       동작대로27길
# 3      여의대방로36길
# 4          보라매로
# 5        만양로14길
# 6           상도로
# 7           대림로
# 8     남부순환로269길
# 9         장승배기로
# 10          상도로
# 11      사당로29가길
# 12       노량진로6길
# 13      사당로16가길
# 14          상도로
# 15       사당로17길
# 16        장승배기로
# 17       사당로26길
# 18         동작대로
# 19         노량진로
# 20     여의대방로44길
# 21         신대방길
# 22       보라매로5길
# 23       보라매로5길
# 24          서달로
# 25        장승배기로
# 26         신대방길
# 27      노량진로12길
# 28       상도로22길
# 29       상도로61길
# ...         ...
# 7142        현충로
# 7143        상도로
# 7144       노량진로
# 7145        상도로
# 7146        상도로
# 7147        대림로
# 7148      여의대방로
# 7149        사당로
# 7150        상도로
# 7151       노량진로
# 7152       노량진로
# 7153       노량진로
# 7154       노량진로
# 7155       노량진로
# 7156       노량진로
# 7157       노량진로
# 7158       노량진로
# 7159       노량진로
# 7160      남부순환로
# 7161      남부순환로
# 7162      남부순환로
# 7163      남부순환로
# 7164        사당로
# 7165        사당로
# 7166        사당로
# 7167        사당로
# 7168        사당로
# 7169        사당로
# 7170        사당로
# 7171        사당로
#
# [7172 rows x 1 columns]

# %%
data2_df= preprocessing(data1_df)
data2_df.rename(columns={'피처': '금연구역 개수'}, inplace=True)
data2_df
# Out:
#             도로명
# 0       동작대로27길
# 1           현충로
# 2       동작대로27길
# 3      여의대방로36길
# 4          보라매로
# 5        만양로14길
# 6           상도로
# 7           대림로
# 8     남부순환로269길
# 9         장승배기로
# 10          상도로
# 11      사당로29가길
# 12       노량진로6길
# 13      사당로16가길
# 14          상도로
# 15       사당로17길
# 16        장승배기로
# 17       사당로26길
# 18         동작대로
# 19         노량진로
# 20     여의대방로44길
# 21         신대방길
# 22       보라매로5길
# 23       보라매로5길
# 24          서달로
# 25        장승배기로
# 26         신대방길
# 27      노량진로12길
# 28       상도로22길
# 29       상도로61길
# ...         ...
# 6779        현충로
# 6780        상도로
# 6781       노량진로
# 6782        상도로
# 6783        상도로
# 6784        대림로
# 6785      여의대방로
# 6786        사당로
# 6787        상도로
# 6788       노량진로
# 6789       노량진로
# 6790       노량진로
# 6791       노량진로
# 6792       노량진로
# 6793       노량진로
# 6794       노량진로
# 6795       노량진로
# 6796       노량진로
# 6797      남부순환로
# 6798      남부순환로
# 6799      남부순환로
# 6800      남부순환로
# 6801        사당로
# 6802        사당로
# 6803        사당로
# 6804        사당로
# 6805        사당로
# 6806        사당로
# 6807        사당로
# 6808        사당로
#
# [6809 rows x 1 columns]
# {'동작대로27길': 84, '현충로': 81, '여의대방로36길': 40, '보라매로': 102, '만양로14길': 54, '상도로': 576, '대림로': 43, '남부순환로269길': 22, '장승배기로': 182, '사당로29가길': 13, '노량진로6길': 20, '사당로16가길': 32, '사당로17길': 34, '사당로26길': 17, '동작대로': 196, '노량진로': 233, '여의대방로44길': 45, '신대방길': 56, '보라매로5길': 80, '서달로': 95, '노량진로12길': 20, '상도로22길': 24, '상도로61길': 44, '서달로14길': 25,
# 13        남부순환로       53
# 14    남부순환로255길        5
# 15   남부순환로257가길        3
# 16   남부순환로259가길        1
# 17    남부순환로259길        1
# 18    남부순환로263길        1
# 19    남부순환로267길        1
# 20    남부순환로269길       22
# 21    남부순환로271길       14
# 22          노들로       24
# 23        노들로2길        4
# 24         노량진로      233
# 25      노량진로10길        5
# 26      노량진로12길       20
# 27     노량진로14가길       17
# 28      노량진로14길       20
# 29     노량진로14다길        2
# ..          ...      ...
# 365    장승배기로24길        1
# 366    장승배기로25길        3
# 367    장승배기로27길        7
# 368    장승배기로28길        7
# 369    장승배기로30길        3
# 370     장승배기로3길        2
# 371     장승배기로4길       10
# 372     장승배기로5길        2
# 373    장승배기로9나길        1
# 374    장승배기로9라길        1
# 375         현충로       81
# 376      현충로10길        6
# 377      현충로12길        1
# 378      현충로14길        3
# 379      현충로16길        1
# 380       현충로4길        2
# 381         흑석로      190
# 382      흑석로11길        4
# 383     흑석로13가길       12
# 384      흑석로13길        8
# 385     흑석로13나길        3
# 386     흑석로13마길        9
# 387     흑석로15가길        1
# 388     흑석로15나길        1
# 389      흑석로6가길        1
# 390       흑석로6길        2
# 391       흑석로7길        7
# 392       흑석로8길       11
# 393       흑석로9길       30
# 394       흑석한강로       32
#
# [395 rows x 2 columns]

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')
data_df['금연구역 개수']= data_df['금연구역 개수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수  담배소매인 지정 업소 개수  음식점 개수  보안등 개수  \
# 0        남부순환로         0            0               6      15       0
# 1         동작대로         2           11              15      73      14
# 2         시흥대로         0            0               6      28      10
# 3        올림픽대로         0            0               0       0       0
# 4         보라매로         2            8               8      53      15
# 5          솔밭로         4           12               2       6      14
# 6          양녕로         9           36               5      48      25
# 7          노들로         0           12               5      39       0
# 8          대림로         1            3               5      34       5
# 9        여의대방로         6           21              11      67      29
# 10         등용로         3           12              11      54      50
# 11         만양로         8           31              18     139      34
# 12         매봉로         3           11               7      16      35
# 13         사당로         3           17              24     199      69
# 14         상도로        10           43              58     292      93
# 15         서달로         4           28               7      35      33
# 16         성대로        14           49               4      32      45
# 17       장승배기로        11           39              22     114      42
# 18         현충로         3           14              14      51      14
# 19         흑석로         4           17              13     170      22
# 20        노량진로         6           26              38     172       9
# 21       흑석한강로         1            3               2       6       0
# 22      강남초등2길         0            0               0       0       2
# 23      강남초등4길         0            0               0       0       4
# 24      강남초등6길         0            0               0       0       5
# 25      강남초등8길         0            0               0       1       3
# 26       강남초등길         2            8               0       2      10
# 27      관악로30길         0            0               0       0       0
# 28      국사봉10길         3           11               1       1      34
# 29      국사봉12길         0            1               0       0       9
# ..         ...       ...          ...             ...     ...     ...
# 655    흑석로10라길         0            0               0       0       4
# 656    흑석로10마길         0            0               0       0       2
# 657     흑석로11길         1            4               0       3       7
# 658    흑석로13가길         0            0               0      11      10
# 659     흑석로13길         1            3               0       3      14
# 660    흑석로13나길         0            0               0       2       0
# 661    흑석로13다길         0            0               0       0       2
# 662    흑석로13라길         0            0               0       0       0
# 663    흑석로13마길         1            2               0      11      17
# 664    흑석로13바길         0            0               0       0      10
# 665    흑석로15가길         0            0               0       0       0
# 666     흑석로15길         0            0               0       0       0
# 667    흑석로15나길         0            0               0       1       0
# 668     흑석로17길         0            0               0       0       0
# 669     흑석로3가길         0            0               0       0       7
# 670      흑석로3길         3            9               1       0      37
# 671      흑석로5길         3            8               1       0      38
# 672     흑석로6가길         0            0               1       1       8
# 673      흑석로6길         2            5               1       6      15
# 674     흑석로6나길         0            0               0       0      11
# 675      흑석로7길         1            4               1       6      16
# 676      흑석로8길         0            0               0      12       6
# 677      흑석로9길         3           12               1      22      30
# 678    노량진로23길         0            0               0       0       0
# 679   동작대로39가길         2            7               1       1      24
# 680  여의대방로24아길         0            0               0       0       0
# 681     보라매로3길         0            0               1      17       0
# 682     보라매로5길         0            1               5      64       5
# 683     보라매로7길         0            0               0       0       1
# 684   여의대방로20길         0            1               4       3       0
#
#      아파트 세대 수  과속방지턱 개수  금연구역 개수
# 0           0         1       53
# 1           0         3      196
# 2           0         0       56
# 3           0         0        0
# 4         494         0      102
# 5          63         9       14
# 6         219         4       73
# 7           0         0       24
# 8           0         2       43
# 9        2389         3      179
# 10        681        23       88
# 11       4245        21      219
# 12       1746        20       54
# 13        120         6      341
# 14       5690        25      576
# 15       1765        14       95
# 16          0         8       55
# 17        400         5      182
# 18       2693         0       81
# 19          0         8      190
# 20        514         3      233
# 21       1518         9       32
# 22          0         0        0
# 23          0         0        0
# 24          0         1        1
# 25          0         1        3
# 26          0         6        4
# 27         40         0        2
# 28          0         1        3
# 29          0         0        0
# ..        ...       ...      ...
# 655         0         0        0
# 656         0         0        0
# 657         0         0        4
# 658         0         0       12
# 659         0         4        8
# 660         0         0        3
# 661         0         0        0
# 662         0         0        0
# 663         0         1        9
# 664         0         0        0
# 665         0         0        1
# 666         0         0        0
# 667         0         0        1
# 668         0         0        0
# 669         0         0        0
# 670         0         0        0
# 671         0         2        0
# 672         0         0        1
# 673         0         3        2
# 674         0         0        0
# 675         0         0        7
# 676         0         0       11
# 677         0         6       30
# 678         0         0        0
# 679       276         1        6
# 680         0         0        0
# 681       256         1       18
# 682       199         9       80
# 683         0         1        0
# 684         0         0        7
#
# [685 rows x 9 columns]

# %% [markdown]
# # 문화유통업소

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\문화유통업소.csv",encoding='cp949')
data1_df.head(5)
# Out:
#         업종            상호                                영업소소재지(도로명)  \
# 0  비디오물제작업         (주)퍼그                 서울특별시 동작구 신대방1가길 38 (신대방동)
# 1  비디오물제작업  (주)예일티브이프로덕션           서울특별시 동작구 여의대방로22길 98  (신대방동,4층)
# 2  비디오물제작업     (주)아이피지박스          서울특별시 동작구 동작대로43길 1-3 (동작동, 성환빌딩)
# 3  비디오물제작업     노마드픽쳐스(주)  서울특별시 동작구 보라매로5가길 7  (신대방동,우성캐릭터그린빌 707호)
# 4  비디오물제작업          원미디어          서울특별시 동작구 상도로37길 45  (상도1동,지하 1층)
#
#      신고(등록)일자 영업상태
# 0  2004-05-19  영업중
# 1  2006-02-23  영업중
# 2  2006-03-09  영업중
# 3  2006-06-19  영업중
# 4  2006-08-04  영업중

# %%
data1_df = data1_df[['영업소소재지(도로명)']]
data1_df[['a','b','도로명','c']]=data1_df['영업소소재지(도로명)'].str.split(' ', n=3, expand=True)
data1_df=data1_df.drop(['영업소소재지(도로명)','a','b','c'],axis=1,inplace=False)
data1_df
# Out:
#           도로명
# 0      신대방1가길
# 1    여의대방로22길
# 2     동작대로43길
# 3     보라매로5가길
# 4      상도로37길
# 5       여의대방로
# 6    여의대방로22길
# 7         현충로
# 8     상도로61가길
# 9      신대방1가길
# 10   여의대방로62길
# 11    동작대로9가길
# 12      국사봉1길
# 13   여의대방로22길
# 14    사당로14가길
# 15   여의대방로22길
# 16   동작대로35가길
# 17   여의대방로22길
# 18   장승배기로30길
# 19        사당로
# 20       노량진로
# 21        상도로
# 22   동작대로35가길
# 23     성대로19길
# 24    양녕로22마길
# 25     사당로2사길
# 26        양녕로
# 27      장승배기로
# 28     보라매로7길
# 29       노량진로
# ..        ...
# 546    노량진로8길
# 547    노량진로8길
# 548    노량진로8길
# 549     국사봉1길
# 550      동작대로
# 551   사당로17가길
# 552   노량진로16길
# 553    상도로61길
# 554    사당로16길
# 555       만양로
# 556       사당로
# 557      노량진로
# 558     흑석로9길
# 559       성대로
# 560      노량진로
# 561       상도로
# 562       상도로
# 563     국사봉1길
# 564      동작대로
# 565       흑석로
# 566    만양로18길
# 567   동작대로27길
# 568     흑석로9길
# 569    상도로67길
# 570       상도로
# 571       만양로
# 572       사당로
# 573       만양로
# 574       만양로
# 575       양녕로
#
# [576 rows x 1 columns]

# %%
data2_df= preprocessing(data1_df)
data2_df.rename(columns={'피처': '문화유통업소 개수'}, inplace=True)
data2_df
# Out:
#           도로명
# 0      신대방1가길
# 1    여의대방로22길
# 2     동작대로43길
# 3     보라매로5가길
# 4      상도로37길
# 5       여의대방로
# 6    여의대방로22길
# 7         현충로
# 8     상도로61가길
# 9      신대방1가길
# 10   여의대방로62길
# 11    동작대로9가길
# 12      국사봉1길
# 13   여의대방로22길
# 14    사당로14가길
# 15   여의대방로22길
# 16   동작대로35가길
# 17   여의대방로22길
# 18   장승배기로30길
# 19        사당로
# 20       노량진로
# 21        상도로
# 22   동작대로35가길
# 23     성대로19길
# 24    양녕로22마길
# 25     사당로2사길
# 26        양녕로
# 27      장승배기로
# 28     보라매로7길
# 29       노량진로
# ..        ...
# 533    노량진로8길
# 534    노량진로8길
# 535    노량진로8길
# 536     국사봉1길
# 537      동작대로
# 538   사당로17가길
# 539   노량진로16길
# 540    상도로61길
# 541    사당로16길
# 542       만양로
# 543       사당로
# 544      노량진로
# 545     흑석로9길
# 546       성대로
# 547      노량진로
# 548       상도로
# 549       상도로
# 550     국사봉1길
# 551      동작대로
# 552       흑석로
# 553    만양로18길
# 554   동작대로27길
# 555     흑석로9길
# 556    상도로67길
# 557       상도로
# 558       만양로
# 559       사당로
# 560       만양로
# 561       만양로
# 562       양녕로
#
# [563 rows x 1 columns]
# {'신대방1가길': 5, '여의대방로22길': 7, '동작대로43길': 3, '보라매로5가길': 7, '상도로37길': 6, '여의대방로': 5, '현충로': 3, '상도로61가길': 1, '여의대방로62길': 4, '동작대로9가길': 1, '국사봉1길': 15, '사당로14가길': 2, '동작대로35가길': 5, '장승배기로30길': 2, '사당로': 29, '노량진로': 23, '상도로': 46, '성대로19길': 1, '양녕로22마길': 1, '사당로2사길': 1, '양녕로': 5, '장승배기로': 9, '보라매로7길': 1, '남부순환로': 4, '동작대로29길': 5, '사당로9라길': 1, '남부순환로271길': 8, '사당로22길': 1, '성대로16길': 1, '대방동1길': 1, '솔밭로': 1, '동작대로15길': 1, '노량진로26길': 1, '보라매로5길': 8, '만양로18길': 8, '동작대로27가길': 10, '동작대로27길': 17, '만양로14가길': 9, '만양로': 25, '흑석로': 18, '흑석로7길': 1, '사당로16길': 8, '상도로61길': 3, '노량진로8길': 9, '남부순환로269길': 2, '장승배기로15길': 1, '상도로34길': 1, '동작대로': 19, '노량진로16길': 8, '사당로16가길': 3, '만양로14길': 8, '노량진로14가길': 2, '국사봉길': 3, '보라매로': 7, '상도로55길': 1, '흑석로9길': 3, '성대로': 8, '등용로': 4, '시흥대로': 5, '만양로8길': 4, '국사봉5길': 2, '상도로62길': 4, '노량진로12길': 3, '노량진로14길': 1, '동작대로25길': 8, '서달로15길': 1, '양녕로22가길': 1, '노량진로6길': 6, '상도로22길': 1, '동작대로3길': 4, '상도로67길': 5, '성대로2길': 5, '보라매로3길': 1, '상도로63길': 1, '흑석로13가길': 2, '양녕로26길': 2, '신대방3길': 2, '신대방길': 6, '동작대로29나길': 1, '등용로14길': 4, '동작대로1길': 10, '여의대방로24길': 7, '동작대로7길': 8, '상도로47길': 1, '사당로29가길': 3, '사당로29길': 1, '동작대로5길': 3, '신대방11길': 1, '사당로14길': 1, '장승배기로16길': 2, '노량진로28길': 2, '등용로4길': 1, '대림로': 7, '사당로28길': 1, '사당로17길': 1, '동작대로27마길': 1, '사당로30길': 8, '흑석로11길': 1, '사당로23길': 2, '서달로': 2, '동작대로27다길': 3, '상도로15길': 2, '동작대로13길': 3, '신대방1길': 1, '상도로36길': 2, '강남초등2길': 1, '매봉로': 2, '대방동15길': 1, '상도로68길': 2, '사당로10길': 1, '성대로6가길': 1, '상도로41길': 3, '동작대로33가길': 1, '동작대로21길': 1, '대방동길': 1, '노량진로18길': 1, '동작대로29가길': 2, '양녕로27길': 1, '성대로1길': 1, '여의대방로24가길': 2, '장승배기로19길': 1, '상도로30길': 1, '동작대로19길': 1, '동작대로27나길': 1, '노량진로10길': 1, '동작대로23길': 1, '사당로17가길': 1}
#            도로명  문화유통업소 개수
# 0       강남초등2길          1
# 1        국사봉1길         15
# 2        국사봉5길          2
# 3         국사봉길          3
# 4        남부순환로          4
# 5    남부순환로269길          2
# 6    남부순환로271길          8
# 7         노량진로         23
# 8      노량진로10길          1
# 9      노량진로12길          3
# 10    노량진로14가길          2
# 11     노량진로14길          1
# 12     노량진로16길          8
# 13     노량진로18길          1
# 14     노량진로26길          1
# 15     노량진로28길          2
# 16      노량진로6길          6
# 17      노량진로8길          9
# 18         대림로          7
# 19      대방동15길          1
# 20       대방동1길          1
# 21        대방동길          1
# 22        동작대로         19
# 23     동작대로13길          3
# 24     동작대로15길          1
# 25     동작대로19길          1
# 26      동작대로1길         10
# 27     동작대로21길          1
# 28     동작대로23길          1
# 29     동작대로25길          8
# ..         ...        ...
# 97       성대로2길          5
# 98      성대로6가길          1
# 99         솔밭로          1
# 100       시흥대로          5
# 101     신대방11길          1
# 102     신대방1가길          5
# 103      신대방1길          1
# 104      신대방3길          2
# 105       신대방길          6
# 106        양녕로          5
# 107    양녕로22가길          1
# 108    양녕로22마길          1
# 109     양녕로26길          2
# 110     양녕로27길          1
# 111      여의대방로          5
# 112   여의대방로22길          7
# 113  여의대방로24가길          2
# 114   여의대방로24길          7
# 115   여의대방로62길          4
# 116      장승배기로          9
# 117   장승배기로15길          1
# 118   장승배기로16길          2
# 119   장승배기로19길          1
# 120   장승배기로30길          2
# 121        현충로          3
# 122        흑석로         18
# 123     흑석로11길          1
# 124    흑석로13가길          2
# 125      흑석로7길          1
# 126      흑석로9길          3
#
# [127 rows x 2 columns]

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')
data_df['문화유통업소 개수']= data_df['문화유통업소 개수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수  담배소매인 지정 업소 개수  음식점 개수  보안등 개수  \
# 0        남부순환로         0            0               6      15       0
# 1         동작대로         2           11              15      73      14
# 2         시흥대로         0            0               6      28      10
# 3        올림픽대로         0            0               0       0       0
# 4         보라매로         2            8               8      53      15
# 5          솔밭로         4           12               2       6      14
# 6          양녕로         9           36               5      48      25
# 7          노들로         0           12               5      39       0
# 8          대림로         1            3               5      34       5
# 9        여의대방로         6           21              11      67      29
# 10         등용로         3           12              11      54      50
# 11         만양로         8           31              18     139      34
# 12         매봉로         3           11               7      16      35
# 13         사당로         3           17              24     199      69
# 14         상도로        10           43              58     292      93
# 15         서달로         4           28               7      35      33
# 16         성대로        14           49               4      32      45
# 17       장승배기로        11           39              22     114      42
# 18         현충로         3           14              14      51      14
# 19         흑석로         4           17              13     170      22
# 20        노량진로         6           26              38     172       9
# 21       흑석한강로         1            3               2       6       0
# 22      강남초등2길         0            0               0       0       2
# 23      강남초등4길         0            0               0       0       4
# 24      강남초등6길         0            0               0       0       5
# 25      강남초등8길         0            0               0       1       3
# 26       강남초등길         2            8               0       2      10
# 27      관악로30길         0            0               0       0       0
# 28      국사봉10길         3           11               1       1      34
# 29      국사봉12길         0            1               0       0       9
# ..         ...       ...          ...             ...     ...     ...
# 655    흑석로10라길         0            0               0       0       4
# 656    흑석로10마길         0            0               0       0       2
# 657     흑석로11길         1            4               0       3       7
# 658    흑석로13가길         0            0               0      11      10
# 659     흑석로13길         1            3               0       3      14
# 660    흑석로13나길         0            0               0       2       0
# 661    흑석로13다길         0            0               0       0       2
# 662    흑석로13라길         0            0               0       0       0
# 663    흑석로13마길         1            2               0      11      17
# 664    흑석로13바길         0            0               0       0      10
# 665    흑석로15가길         0            0               0       0       0
# 666     흑석로15길         0            0               0       0       0
# 667    흑석로15나길         0            0               0       1       0
# 668     흑석로17길         0            0               0       0       0
# 669     흑석로3가길         0            0               0       0       7
# 670      흑석로3길         3            9               1       0      37
# 671      흑석로5길         3            8               1       0      38
# 672     흑석로6가길         0            0               1       1       8
# 673      흑석로6길         2            5               1       6      15
# 674     흑석로6나길         0            0               0       0      11
# 675      흑석로7길         1            4               1       6      16
# 676      흑석로8길         0            0               0      12       6
# 677      흑석로9길         3           12               1      22      30
# 678    노량진로23길         0            0               0       0       0
# 679   동작대로39가길         2            7               1       1      24
# 680  여의대방로24아길         0            0               0       0       0
# 681     보라매로3길         0            0               1      17       0
# 682     보라매로5길         0            1               5      64       5
# 683     보라매로7길         0            0               0       0       1
# 684   여의대방로20길         0            1               4       3       0
#
#      아파트 세대 수  과속방지턱 개수  금연구역 개수  문화유통업소 개수
# 0           0         1       53          4
# 1           0         3      196         19
# 2           0         0       56          5
# 3           0         0        0          0
# 4         494         0      102          7
# 5          63         9       14          1
# 6         219         4       73          5
# 7           0         0       24          0
# 8           0         2       43          7
# 9        2389         3      179          5
# 10        681        23       88          4
# 11       4245        21      219         25
# 12       1746        20       54          2
# 13        120         6      341         29
# 14       5690        25      576         46
# 15       1765        14       95          2
# 16          0         8       55          8
# 17        400         5      182          9
# 18       2693         0       81          3
# 19          0         8      190         18
# 20        514         3      233         23
# 21       1518         9       32          0
# 22          0         0        0          1
# 23          0         0        0          0
# 24          0         1        1          0
# 25          0         1        3          0
# 26          0         6        4          0
# 27         40         0        2          0
# 28          0         1        3          0
# 29          0         0        0          0
# ..        ...       ...      ...        ...
# 655         0         0        0          0
# 656         0         0        0          0
# 657         0         0        4          1
# 658         0         0       12          2
# 659         0         4        8          0
# 660         0         0        3          0
# 661         0         0        0          0
# 662         0         0        0          0
# 663         0         1        9          0
# 664         0         0        0          0
# 665         0         0        1          0
# 666         0         0        0          0
# 667         0         0        1          0
# 668         0         0        0          0
# 669         0         0        0          0
# 670         0         0        0          0
# 671         0         2        0          0
# 672         0         0        1          0
# 673         0         3        2          0
# 674         0         0        0          0
# 675         0         0        7          1
# 676         0         0       11          0
# 677         0         6       30          3
# 678         0         0        0          0
# 679       276         1        6          0
# 680         0         0        0          0
# 681       256         1       18          1
# 682       199         9       80          8
# 683         0         1        0          1
# 684         0         0        7          0
#
# [685 rows x 10 columns]

# %% [markdown]
# # 임대주택

# %%
data1_df=pd.read_csv("C:\\Users\\intae\\Desktop\\공모전\\임대주택.csv",encoding='cp949')
data1_df
# Out:
#         영업구분      사업자구분                                      임대물건지 주소 임대주택 구분  \
# 0      등록영업중      임대사업자                      동작구 사당로14길 25 (사당동) 2동동   매입임대주택
# 1      등록영업중      임대사업자    동작구 여의대방로10길 38 (신대방동, 보라매롯데낙천대아파트) 107동동   매입임대주택
# 2      등록영업중      임대사업자                 동작구 노량진로 140 (노량진동) 메가스터디타워동   매입임대주택
# 3      등록영업중      임대사업자                        동작구 국사봉2나길 8-6 (신대방동)   매입임대주택
# 4      등록영업중      임대사업자               동작구 장승배기로24길 32 (노량진동, 살렘 하우스)   매입임대주택
# 5      등록영업중      임대사업자                        동작구 노량진로6다길 13 (노량진동)   매입임대주택
# 6      등록영업중      임대사업자          동작구 만양로 19 (노량진동, 신동아리버파크아파트) 703동동   매입임대주택
# 7      등록영업중      임대사업자          동작구 만양로 19 (노량진동, 신동아리버파크아파트) 703동동   매입임대주택
# 8      등록영업중      임대사업자         동작구 상도로53길 8 (상도동, 래미안상도3차아파트) 306동동   매입임대주택
# 9      등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 10     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 11     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 12     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 13     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 14     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 15     등록영업중      임대사업자             동작구 현충로 151 (흑석동, 한강현대아파트) 101동동   매입임대주택
# 16     등록영업중      임대사업자             동작구 현충로 151 (흑석동, 한강현대아파트) 101동동   매입임대주택
# 17     등록영업중      임대사업자                  동작구 노량진로28길 32-3 (본동, 한강파크)   매입임대주택
# 18     등록영업중      임대사업자                동작구 장승배기로16길 23 (노량진동, 월드쉐르빌)   매입임대주택
# 19     등록영업중      임대사업자        동작구 노량진동 57-1 외 3필지 메가스터디타워 17층 1720호   매입임대주택
# 20     등록영업중      임대사업자                  동작구 노량진로28길 32-3 (본동, 한강파크)   매입임대주택
# 21     등록영업중      임대사업자          동작구 동작대로29길 110 (사당동, 신동아아파트) 405동동   매입임대주택
# 22     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 23     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 24     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 25     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 26     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 27     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 28     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# 29     등록영업중      임대사업자                  동작구 상도로15길 110-1 (상도동, 백호빌)   건설임대주택
# ...      ...        ...                                           ...     ...
# 21467  전입영업중  허가건설임대사업자                    동작구 대방동 1-11 천록빌라 2층 213호   건설임대주택
#
#           임대주택 종류    임대주택 유형
# 0      장기일반민간임대주택      다세대주택
# 1      장기일반민간임대주택        아파트
# 2        단기민간임대주택        아파트
# 3        단기민간임대주택      다세대주택
# 4      장기일반민간임대주택      다세대주택
# 5      장기일반민간임대주택       단독주택
# 6        단기민간임대주택        아파트
# 7        단기민간임대주택        아파트
# 8      장기일반민간임대주택        아파트
# 9        단기민간임대주택      다세대주택
# 10       단기민간임대주택      다세대주택
# 11       단기민간임대주택      다세대주택
# 12       단기민간임대주택      다세대주택
# 13       단기민간임대주택      다세대주택
# 14       단기민간임대주택      다세대주택
# 15     장기일반민간임대주택        아파트
# 16     장기일반민간임대주택        아파트
# 17       단기민간임대주택      다세대주택
# 18     장기일반민간임대주택      다세대주택
# 19         매입임대주택  준주택(오피스텔)
# 20       단기민간임대주택      다세대주택
# 21     장기일반민간임대주택        아파트
# 22             기타      다세대주택
# 23             기타      다세대주택
# 24             기타      다세대주택
# 25             기타      다세대주택
# 26             기타      다세대주택
# 27             기타      다세대주택
# 28             기타      다세대주택
# 29             기타      다세대주택
# ...           ...        ...
# 21438          기타        아파트
# 21439          기타       연립주택
# 21440          기타       연립주택
# 21441          기타       연립주택
# 21442          기타       연립주택
# 21443          기타       연립주택
# 21444          기타       연립주택
# 21445          기타       연립주택
# 21446          기타       연립주택
# 21447          기타       연립주택
# 21448          기타       연립주택
# 21449          기타       연립주택
# 21450          기타       연립주택
# 21451          기타       연립주택
# 21452          기타       연립주택
# 21453          기타       연립주택
# 21454          기타       연립주택
# 21455          기타       연립주택
# 21456          기타       연립주택
# 21457          기타       연립주택
# 21458          기타       연립주택
# 21459          기타       연립주택
# 21460          기타       연립주택
# 21461          기타       연립주택
# 21462          기타       연립주택
# 21463          기타       연립주택
# 21464          기타       연립주택
# 21465          기타       연립주택
# 21466          기타       연립주택
# 21467          기타       연립주택
#
# [21468 rows x 6 columns]

# %%
data1_df = data1_df[['임대물건지 주소']]
data1_df['임대물건지 주소'] = data1_df['임대물건지 주소'].str.lstrip()
data1_df
# Out:
# C:\Users\intae\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                          임대물건지 주소
# 0                        동작구 사당로14길 25 (사당동) 2동동
# 1      동작구 여의대방로10길 38 (신대방동, 보라매롯데낙천대아파트) 107동동
# 2                   동작구 노량진로 140 (노량진동) 메가스터디타워동
# 3                          동작구 국사봉2나길 8-6 (신대방동)
# 4                 동작구 장승배기로24길 32 (노량진동, 살렘 하우스)
# 5                          동작구 노량진로6다길 13 (노량진동)
# 6            동작구 만양로 19 (노량진동, 신동아리버파크아파트) 703동동
# 7            동작구 만양로 19 (노량진동, 신동아리버파크아파트) 703동동
# 8           동작구 상도로53길 8 (상도동, 래미안상도3차아파트) 306동동
# 9                    동작구 상도로15길 110-1 (상도동, 백호빌)
# 10                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 11                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 12                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 13                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 14                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 15              동작구 현충로 151 (흑석동, 한강현대아파트) 101동동
# 16              동작구 현충로 151 (흑석동, 한강현대아파트) 101동동
# 17                   동작구 노량진로28길 32-3 (본동, 한강파크)
# 18                 동작구 장승배기로16길 23 (노량진동, 월드쉐르빌)
# 19         동작구 노량진동 57-1 외 3필지 메가스터디타워 17층 1720호
# 20                   동작구 노량진로28길 32-3 (본동, 한강파크)
# 21           동작구 동작대로29길 110 (사당동, 신동아아파트) 405동동
# 22                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 23                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 24                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 25                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 26                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 27                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 28                   동작구 상도로15길 110-1 (상도동, 백호빌)
# 29                   동작구 상도로15길 110-1 (상도동, 백호빌)
# ...                                           ...
# 21438      동작구 대방동 510 외1필지 대방동신일해피트리 101동 1304호
# 21439                  동작구 대방동 1-11 천록빌라 2층 202호
# 21440                  동작구 대방동 1-11 천록빌라 3층 309호
# 21441                  동작구 대방동 1-11 천록빌라 3층 307호
# 21442                  동작구 대방동 1-11 천록빌라 1층 111호
# 21443                  동작구 대방동 1-11 천록빌라 3층 312호
# 21444                  동작구 대방동 1-11 천록빌라 2층 206호
# 21445                  동작구 대방동 1-11 천록빌라 1층 108호
# 21446                  동작구 대방동 1-11 천록빌라 3층 305호
# 21447                  동작구 대방동 1-11 천록빌라 3층 310호
# 21448                  동작구 대방동 1-11 천록빌라 1층 110호
# 21449                  동작구 대방동 1-11 천록빌라 1층 102호
# 21450                  동작구 대방동 1-11 천록빌라 1층 103호
# 21451                  동작구 대방동 1-11 천록빌라 2층 201호
# 21452                  동작구 대방동 1-11 천록빌라 1층 113호
# 21453                  동작구 대방동 1-11 천록빌라 1층 105호
# 21454                  동작구 대방동 1-11 천록빌라 1층 101호
# 21455                  동작구 대방동 1-11 천록빌라 3층 308호
# 21456                  동작구 대방동 1-11 천록빌라 3층 303호
# 21457                  동작구 대방동 1-11 천록빌라 3층 306호
# 21458                  동작구 대방동 1-11 천록빌라 1층 112호
# 21459                  동작구 대방동 1-11 천록빌라 3층 311호
# 21460                  동작구 대방동 1-11 천록빌라 1층 107호
# 21461                  동작구 대방동 1-11 천록빌라 3층 301호
# 21462                  동작구 대방동 1-11 천록빌라 3층 313호
# 21463                  동작구 대방동 1-11 천록빌라 1층 106호
# 21464                  동작구 대방동 1-11 천록빌라 1층 109호
# 21465                  동작구 대방동 1-11 천록빌라 2층 212호
# 21466                  동작구 대방동 1-11 천록빌라 3층 302호
# 21467                  동작구 대방동 1-11 천록빌라 2층 213호
#
# [21468 rows x 1 columns]

# %%
data1_df[['a','도로명','b']]=data1_df['임대물건지 주소'].str.split(' ', n=2, expand=True)
data1_df=data1_df.drop(['임대물건지 주소','a','b'],axis=1,inplace=False)
data1_df
# Out:
#             도로명
# 0        사당로14길
# 1      여의대방로10길
# 2          노량진로
# 3        국사봉2나길
# 4      장승배기로24길
# 5       노량진로6다길
# 6           만양로
# 7           만양로
# 8        상도로53길
# 9        상도로15길
# 10       상도로15길
# 11       상도로15길
# 12       상도로15길
# 13       상도로15길
# 14       상도로15길
# 15          현충로
# 16          현충로
# 17      노량진로28길
# 18     장승배기로16길
# 19         노량진동
# 20      노량진로28길
# 21      동작대로29길
# 22       상도로15길
# 23       상도로15길
# 24       상도로15길
# 25       상도로15길
# 26       상도로15길
# 27       상도로15길
# 28       상도로15길
# 29       상도로15길
# ...         ...
# 21438       대방동
# 21439       대방동
# 21440       대방동
# 21441       대방동
# 21442       대방동
# 21443       대방동
# 21444       대방동
# 21445       대방동
# 21446       대방동
# 21447       대방동
# 21448       대방동
# 21449       대방동
# 21450       대방동
# 21451       대방동
# 21452       대방동
# 21453       대방동
# 21454       대방동
# 21455       대방동
# 21456       대방동
# 21457       대방동
# 21458       대방동
# 21459       대방동
# 21460       대방동
# 21461       대방동
# 21462       대방동
# 21463       대방동
# 21464       대방동
# 21465       대방동
# 21466       대방동
# 21467       대방동
#
# [21468 rows x 1 columns]

# %%
data2_df= preprocessing(data1_df)
data2_df.rename(columns={'피처': '임대주택 개수'}, inplace=True)
data2_df
# Out:
#               도로명
# 0          사당로14길
# 1        여의대방로10길
# 2            노량진로
# 3          국사봉2나길
# 4        장승배기로24길
# 5         노량진로6다길
# 6             만양로
# 7             만양로
# 8          상도로53길
# 9          상도로15길
# 10         상도로15길
# 11         상도로15길
# 12         상도로15길
# 13         상도로15길
# 14         상도로15길
# 15            현충로
# 16            현충로
# 17        노량진로28길
# 18       장승배기로16길
# 19        노량진로28길
# 20        동작대로29길
# 21         상도로15길
# 22         상도로15길
# 23         상도로15길
# 24         상도로15길
# 25         상도로15길
# 26         상도로15길
# 27         상도로15길
# 28         상도로15길
# 29         상도로15길
# ...           ...
# 15045        알마타길
# 15046        알마타길
# 15047        알마타길
# 15048        알마타길
# 15049        알마타길
# 15050        알마타길
# 15051        알마타길
# 15052        알마타길
# 15053     성대로12가길
# 15054     성대로12가길
# 15055     성대로12가길
# 15056     성대로12가길
# 15057     성대로12가길
# 15058     성대로12가길
# 15059     성대로12가길
# 15060    노량진로23가길
# 15061       만양로8길
# 15062       만양로8길
# 15063       만양로8길
# 15064       만양로8길
# 15065       만양로8길
# 15066       만양로8길
# 15067       만양로8길
# 15068       만양로8길
# 15069       만양로8길
# 15070         서달로
# 15071     동작대로13길
# 15072      서달로6가길
# 15073     노량진로6마길
# 15074  남부순환로267가길
#
# [15075 rows x 1 columns]
# 10        국사봉1길       25
# 11       국사봉2가길        6
# 12        국사봉2길       77
# 13       국사봉2나길        6
# 14       국사봉2다길       16
# 15       국사봉2바길       15
# 16        국사봉3길        1
# 17        국사봉5길       11
# 18        국사봉6길       92
# 19        국사봉7길        1
# 20        국사봉8길       63
# 21         국사봉길      107
# 22        남부순환로       63
# 23   남부순환로255가길        3
# 24    남부순환로255길       24
# 25   남부순환로255나길       19
# 26   남부순환로255다길        6
# 27   남부순환로255마길        6
# 28   남부순환로255바길        6
# 29   남부순환로257가길       51
# ..          ...      ...
# 485         현충로       77
# 486      현충로10길       34
# 487     현충로12가길        2
# 488      현충로12길       16
# 489     현충로14가길        2
# 490      현충로14길        5
# 491     현충로14나길        4
# 492     현충로14다길        1
# 493      현충로16길        2
# 494      현충로18길        3
# 495      현충로20길        5
# 496      현충로22길       13
# 497     현충로24가길        1
# 498      현충로24길        4
# 499       현충로2길        1
# 500       현충로4길        2
# 501         흑석로      125
# 502      흑석로10길        1
# 503      흑석로11길        5
# 504     흑석로13가길       25
# 505     흑석로13마길       18
# 506     흑석로13바길       31
# 507       흑석로3길       18
# 508       흑석로5길       77
# 509      흑석로6가길       13
# 510       흑석로6길        3
# 511      흑석로6나길        4
# 512       흑석로7길        1
# 513       흑석로9길       51
# 514       흑석한강로       55
#
# [515 rows x 2 columns]

# %%
data_df=pd.merge(data_df,data2_df,on='도로명',how='left')
data_df['임대주택 개수']= data_df['임대주택 개수'].fillna(0).astype('int')
data_df
# Out:
#            도로명  안전비상벨 개수  CCTV 카메라 개수  담배소매인 지정 업소 개수  음식점 개수  보안등 개수  \
# 0        남부순환로         0            0               6      15       0
# 1         동작대로         2           11              15      73      14
# 2         시흥대로         0            0               6      28      10
# 3        올림픽대로         0            0               0       0       0
# 4         보라매로         2            8               8      53      15
# 5          솔밭로         4           12               2       6      14
# 6          양녕로         9           36               5      48      25
# 7          노들로         0           12               5      39       0
# 8          대림로         1            3               5      34       5
# 9        여의대방로         6           21              11      67      29
# 10         등용로         3           12              11      54      50
# 11         만양로         8           31              18     139      34
# 12         매봉로         3           11               7      16      35
# 13         사당로         3           17              24     199      69
# 14         상도로        10           43              58     292      93
# 15         서달로         4           28               7      35      33
# 16         성대로        14           49               4      32      45
# 17       장승배기로        11           39              22     114      42
# 18         현충로         3           14              14      51      14
# 19         흑석로         4           17              13     170      22
# 20        노량진로         6           26              38     172       9
# 21       흑석한강로         1            3               2       6       0
# 22      강남초등2길         0            0               0       0       2
# 23      강남초등4길         0            0               0       0       4
# 24      강남초등6길         0            0               0       0       5
# 25      강남초등8길         0            0               0       1       3
# 26       강남초등길         2            8               0       2      10
# 27      관악로30길         0            0               0       0       0
# 28      국사봉10길         3           11               1       1      34
# 29      국사봉12길         0            1               0       0       9
# ..         ...       ...          ...             ...     ...     ...
# 655    흑석로10라길         0            0               0       0       4
# 656    흑석로10마길         0            0               0       0       2
# 657     흑석로11길         1            4               0       3       7
# 658    흑석로13가길         0            0               0      11      10
# 659     흑석로13길         1            3               0       3      14
# 660    흑석로13나길         0            0               0       2       0
# 661    흑석로13다길         0            0               0       0       2
# 662    흑석로13라길         0            0               0       0       0
# 663    흑석로13마길         1            2               0      11      17
# 664    흑석로13바길         0            0               0       0      10
# 665    흑석로15가길         0            0               0       0       0
# 666     흑석로15길         0            0               0       0       0
# 667    흑석로15나길         0            0               0       1       0
# 668     흑석로17길         0            0               0       0       0
# 669     흑석로3가길         0            0               0       0       7
# 670      흑석로3길         3            9               1       0      37
# 671      흑석로5길         3            8               1       0      38
# 672     흑석로6가길         0            0               1       1       8
# 673      흑석로6길         2            5               1       6      15
# 674     흑석로6나길         0            0               0       0      11
# 675      흑석로7길         1            4               1       6      16
# 676      흑석로8길         0            0               0      12       6
# 677      흑석로9길         3           12               1      22      30
# 678    노량진로23길         0            0               0       0       0
# 679   동작대로39가길         2            7               1       1      24
# 680  여의대방로24아길         0            0               0       0       0
# 681     보라매로3길         0            0               1      17       0
# 682     보라매로5길         0            1               5      64       5
# 683     보라매로7길         0            0               0       0       1
# 684   여의대방로20길         0            1               4       3       0
#
#      아파트 세대 수  과속방지턱 개수  금연구역 개수  문화유통업소 개수  임대주택 개수
# 0           0         1       53          4       63
# 1           0         3      196         19        6
# 2           0         0       56          5      132
# 3           0         0        0          0        0
# 4         494         0      102          7       69
# 5          63         9       14          1        4
# 6         219         4       73          5       64
# 7           0         0       24          0        0
# 8           0         2       43          7       14
# 9        2389         3      179          5      127
# 10        681        23       88          4      191
# 11       4245        21      219         25      185
# 12       1746        20       54          2      100
# 13        120         6      341         29      221
# 14       5690        25      576         46      770
# 15       1765        14       95          2       56
# 16          0         8       55          8       56
# 17        400         5      182          9       26
# 18       2693         0       81          3       77
# 19          0         8      190         18      125
# 20        514         3      233         23      627
# 21       1518         9       32          0       55
# 22          0         0        0          1       27
# 23          0         0        0          0        7
# 24          0         1        1          0        0
# 25          0         1        3          0        2
# 26          0         6        4          0       48
# 27         40         0        2          0        2
# 28          0         1        3          0       69
# 29          0         0        0          0       12
# ..        ...       ...      ...        ...      ...
# 655         0         0        0          0        0
# 656         0         0        0          0        0
# 657         0         0        4          1        5
# 658         0         0       12          2       25
# 659         0         4        8          0        0
# 660         0         0        3          0        0
# 661         0         0        0          0        0
# 662         0         0        0          0        0
# 663         0         1        9          0       18
# 664         0         0        0          0       31
# 665         0         0        1          0        0
# 666         0         0        0          0        0
# 667         0         0        1          0        0
# 668         0         0        0          0        0
# 669         0         0        0          0        0
# 670         0         0        0          0       18
# 671         0         2        0          0       77
# 672         0         0        1          0       13
# 673         0         3        2          0        3
# 674         0         0        0          0        4
# 675         0         0        7          1        1
# 676         0         0       11          0        0
# 677         0         6       30          3       51
# 678         0         0        0          0        0
# 679       276         1        6          0        2
# 680         0         0        0          0        0
# 681       256         1       18          1        3
# 682       199         9       80          8        6
# 683         0         1        0          1        0
# 684         0         0        7          0        0
#
# [685 rows x 11 columns]

# %%
data_df.to_csv("C:\\Users\\intae\\Desktop\\공모전\\동작구.csv",header=True,index=False)
